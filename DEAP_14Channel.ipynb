# %% [markdown]
# # IMPORT REQUIRED LIBRARIES

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://github.com/forrestbao/pyeeg.git
import pyeeg as pe

# !pip install mne
import mne

import os
import time
import pickle
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
# %matplotlib inline

import scipy.signal

from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
# Out:
# Collecting git+https://github.com/forrestbao/pyeeg.git
#   Cloning https://github.com/forrestbao/pyeeg.git to /tmp/pip-req-build-8g_htucy
#   Running command git clone --filter=blob:none --quiet https://github.com/forrestbao/pyeeg.git /tmp/pip-req-build-8g_htucy
#   Resolved https://github.com/forrestbao/pyeeg.git to commit a6c18bb093e4748f9d9c208535a6ae024a0802b8
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from pyeeg==0.4.4) (1.23.5)
# Building wheels for collected packages: pyeeg
#   Building wheel for pyeeg (setup.py) ... done
#   Created wheel for pyeeg: filename=pyeeg-0.4.4-py2.py3-none-any.whl size=28111 sha256=d4a90a939332c68cb15f0f0b6a4edde656d9fd72cda606816c8597ed826228e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xb78pe30/wheels/a8/c4/1a/cee09dcc12a11620066d35ace42e3c1e3bfbcc1db3a0ce7788
# Successfully built pyeeg
# Installing collected packages: pyeeg
# Successfully installed pyeeg-0.4.4
# Collecting mne
#   Downloading mne-1.6.0-py3-none-any.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 34.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from mne) (1.23.5)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from mne) (1.11.4)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from mne) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.66.1)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (23.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.2)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne) (0.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from mne) (0.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (4.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2023.11.17)
# Installing collected packages: mne
# Successfully installed mne-1.6.0

# %%
import torch
# Check CUDA
CUDA = torch.cuda.is_available()
print("CUDA Availability: ", CUDA)
if CUDA:
    torch.backends.cudnn.benchmark = True
    device = torch.device('cuda:0')
    # !nvidia-smi
else:
    device = torch.device('cpu')
# Out:
# CUDA Availability:  True
# Mon Dec 25 08:08:37 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0              24W / 300W |      2MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # DATA PREPROCESS

# %%
deapdataset = '/content/drive/MyDrive/EEGDATA/deap_data'
seeddataset = '/content/drive/MyDrive/EEGDATA/seed_data'

channel_14 = [1,2,3,4,6,11,13,17,19,20,21,25,29,31] # 14 Channels chosen to fit Emotiv Epoch+ (AF3、F3、F7、FC5、T7、P7、O1、AF4、F4、F8、FC6、T8、P8、O2)
eeg_channel_14 = ["AF3", "F3", "F7", "FC5", "T7", "P7", "O1", "AF4", "F4", "F8", "FC6", "T8", "P8", "O2"]

channel_32 = [i for i in range(32)]# All Channels
eeg_channel_32 = ["Fp1", "AF3", "F3", "F7", "FC5", "FC1", "C3", "T7", "CP5", "CP1", "P3", "P7", "PO3", "O1", "Oz", "Pz",
                  "Fp2", "AF4", "Fz", "F4", "F8", "FC6", "FC2", "Cz", "C4", "T8", "CP6", "CP2", "P4", "P8", "PO4", "O2"]

# Create a standard montage for the Biosemi 32 channel layout
full_montage = mne.channels.make_standard_montage('biosemi32')
# Extract the positions of your 14 channels from the full montage
selected_ch_14 = {ch: full_montage.get_positions()['ch_pos'][ch] for ch in eeg_channel_14}
selected_ch_32 = {ch: full_montage.get_positions()['ch_pos'][ch] for ch in eeg_channel_32}
# Create a custom montage using the selected channel positions
custom_montage_14 = mne.channels.make_dig_montage(ch_pos=selected_ch_14)
custom_montage_32 = mne.channels.make_dig_montage(ch_pos=selected_ch_32)

band = [4,8,12,16,25,45] # 5 bands
window_size = 256 # Averaging band power of 2 sec
step_size = 16 # Each 0.125 sec update once
sample_rate = 128 # Sampling rate of 128 Hz

# %%
def RAW_Processing(sub, channel, band, window_size, step_size, sample_rate):

    meta = []
    with open(deapdataset + "/s" + sub + '.dat', 'rb') as file:

        subject = pickle.load(file, encoding='latin1') #resolve the python 2 data problem by encoding : latin1

        for i in range (0,40):
            # loop over 0-39 trails
            data = subject["data"][i] #EEG SIGNAL
            #print(data)
            labels = subject["labels"][i] #EMOTION LABEL
            #print(labels)
            start = 0;

            while start + window_size < data.shape[1]:
                meta_array = []
                meta_data = []

                meta_data = [data[j][start : start + window_size] for j in channel]
                # print(np.array(meta_data))

                meta_array.append(np.array(meta_data))
                meta_array.append(labels)

                meta.append(np.array(meta_array, dtype=object))
                start = start + step_size

        meta = np.array(meta)
        print(meta.shape)
        np.save('/content/temp/s' + sub, meta, allow_pickle=True, fix_imports=True)

# %%
def FFT_Processing(sub, channel, band, window_size, step_size, sample_rate):
    '''
    arguments:  string subject
                list channel indice
                list band
                int window size for FFT
                int step size for FFT
                int sample rate for FFT
    return:     void
    '''
    meta = []
    with open(deapdataset + "/s" + sub + '.dat', 'rb') as file:

        subject = pickle.load(file, encoding='latin1') #resolve the python 2 data problem by encoding : latin1

        for i in range (0,40):
            # loop over 0-39 trails
            data = subject["data"][i] #EEG SIGNAL
            #print(data)
            labels = subject["labels"][i] #EMOTION LABEL
            #print(labels)
            start = 0;

            while start + window_size < data.shape[1]:
                meta_array = []
                meta_data = []

                for j in channel:
                    X = data[j][start : start + window_size]
                    Y = pe.bin_power(X, band, sample_rate)
                    meta_data = meta_data + list(Y[0])


                meta_array.append(np.array(meta_data))
                meta_array.append(labels)

                meta.append(np.array(meta_array, dtype=object))
                start = start + step_size

        meta = np.array(meta)
        print(meta.shape)
        np.save('/content/temp/s' + sub, meta, allow_pickle=True, fix_imports=True)

# %% [markdown]
# # DATASET CREATE & SAVE

# %%
# !rm -r /content/temp
# !mkdir /content/temp

data_type = 'RAW'
subjectNum = 10
files = []
for n in range(1, subjectNum+1):
    s = ''
    if n < 10:
        s += '0'
    s += str(n)
    files.append(s)

subjectList = files
print("Datatype: " + data_type)
print(subjectList)
# Out:
# rm: cannot remove '/content/temp': No such file or directory
# Datatype: RAW
# ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10']

# %%
if data_type == 'RAW':
  for subjects in subjectList:
      RAW_Processing(subjects, channel_14, band, window_size, step_size, sample_rate)
elif data_type == 'FFT':
  for subjects in subjectList:
      FFT_Processing(subjects, channel_32, band, window_size, step_size, sample_rate)
# Out:
# (19520, 2)
# (19520, 2)
# (19520, 2)
# (19520, 2)
# (19520, 2)
# (19520, 2)
# (19520, 2)
# (19520, 2)
# (19520, 2)
# (19520, 2)

# %%
data_training = []
label_training = []
data_testing = []
label_testing = []
data_info = '_10_14' #num_subject + num_channel


for subjects in subjectList:
    with open('/content/temp/s' + subjects + '.npy', 'rb') as file:
      sub = np.load(file,allow_pickle=True)

      for i in range (0,sub.shape[0]):
        if i % 5 == 0:
          data_testing.append(sub[i][0])
          label_testing.append(sub[i][1])
        else:
          data_training.append(sub[i][0])
          label_training.append(sub[i][1])

data_training  = np.array(data_training)
label_training = np.array(label_training)
data_testing   = np.array(data_testing)
label_testing  = np.array(label_testing)

# !mkdir /content/drive/MyDrive/EEGDATA/temp/

if data_type == 'FFT':
  np.save('/content/drive/MyDrive/EEGDATA/temp/fft_data_training' + data_info, data_training, allow_pickle=True, fix_imports=True)
  np.save('/content/drive/MyDrive/EEGDATA/temp/fft_label_training' + data_info, label_training, allow_pickle=True, fix_imports=True)
  print("FFT training dataset:", data_training.shape, label_training.shape)

  np.save('/content/drive/MyDrive/EEGDATA/temp/fft_data_testing' + data_info, data_testing, allow_pickle=True, fix_imports=True)
  np.save('/content/drive/MyDrive/EEGDATA/temp/fft_label_testing' + data_info, label_testing, allow_pickle=True, fix_imports=True)
  print("FFT testing dataset:", data_testing.shape, label_testing.shape)

else:
  np.save('/content/drive/MyDrive/EEGDATA/temp/data_training' + data_info, data_training, allow_pickle=True, fix_imports=True)
  np.save('/content/drive/MyDrive/EEGDATA/temp/label_training' + data_info, label_training, allow_pickle=True, fix_imports=True)
  print("training dataset:", data_training.shape, label_training.shape)

  np.save('/content/drive/MyDrive/EEGDATA/temp/data_testing' + data_info, data_testing, allow_pickle=True, fix_imports=True)
  np.save('/content/drive/MyDrive/EEGDATA/temp/label_testing' + data_info, label_testing, allow_pickle=True, fix_imports=True)
  print("testing dataset:", data_testing.shape, label_testing.shape)
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/EEGDATA/temp/’: File exists
# training dataset: (156160, 14, 256) (156160, 4)
# testing dataset: (39040, 14, 256) (39040, 4)

# %% [markdown]
# # DATASET LOAD

# %%
data_type = 'RAW'
data_info = '_10_14' #num_subject + num_channel

# %%
if data_type == 'FFT':
  # Loading training data
  data_training = np.load('/content/drive/MyDrive/EEGDATA/temp/fft_data_training' + data_info + '.npy', allow_pickle=True)
  label_training = np.load('/content/drive/MyDrive/EEGDATA/temp/fft_label_training' + data_info + '.npy', allow_pickle=True)

  # Loading testing data
  data_testing = np.load('/content/drive/MyDrive/EEGDATA/temp/fft_data_testing' + data_info + '.npy', allow_pickle=True)
  label_testing = np.load('/content/drive/MyDrive/EEGDATA/temp/fft_label_testing' + data_info + '.npy', allow_pickle=True)

  data_training = data_training.reshape(data_training.shape[0],1,data_training.shape[1])
  data_testing = data_testing.reshape(data_testing.shape[0],1,data_testing.shape[1])

  print("Loaded FFT training dataset:", data_training.shape, label_training.shape)
  print("Loaded FFT testing dataset:", data_testing.shape, label_testing.shape)

else:
  # Loading training data
  data_training = np.load('/content/drive/MyDrive/EEGDATA/temp/data_training' + data_info + '.npy', allow_pickle=True)
  label_training = np.load('/content/drive/MyDrive/EEGDATA/temp/label_training' + data_info + '.npy', allow_pickle=True)

  # Loading testing data
  data_testing = np.load('/content/drive/MyDrive/EEGDATA/temp/data_testing' + data_info + '.npy', allow_pickle=True)
  label_testing = np.load('/content/drive/MyDrive/EEGDATA/temp/label_testing' + data_info + '.npy', allow_pickle=True)

  print("Loaded RAW training dataset:", data_training.shape, label_training.shape)
  print("Loaded RAW testing dataset:", data_testing.shape, label_testing.shape)
# Out:
# Loaded RAW training dataset: (156160, 14, 256) (156160, 4)
# Loaded RAW testing dataset: (39040, 14, 256) (39040, 4)

# %%
print(data_training.shape)
print(label_training.shape)
print(data_testing.shape)
print(label_testing.shape)
# Out:
# (156160, 14, 256)
# (156160, 4)
# (39040, 14, 256)
# (39040, 4)

# %%
label_training
# Out:
# array([[7.71, 7.6 , 6.9 , 7.83],
#        [7.71, 7.6 , 6.9 , 7.83],
#        [7.71, 7.6 , 6.9 , 7.83],
#        ...,
#        [5.78, 6.15, 7.04, 6.44],
#        [5.78, 6.15, 7.04, 6.44],
#        [5.78, 6.15, 7.04, 6.44]])

# %% [markdown]
# # DATASET VISUALIZAION

# %%
# Create a sample Raw data object with these channels
info_14 = mne.create_info(ch_names=eeg_channel_14, sfreq=256, ch_types='eeg')
raw_14 = mne.io.RawArray(np.zeros((14, 1)), info_14)

# Apply the custom montage to the Raw object
raw_14.set_montage(custom_montage_14)

# Visualize the electrode layout
custom_montage_14.plot()
# Out:
# Creating RawArray with float64 data, n_channels=14, n_times=1
#     Range : 0 ... 0 =      0.000 ...     0.000 secs
# Ready.
# <ipython-input-12-d246b76a61e6>:6: RuntimeWarning: Fiducial point nasion not found, assuming identity unknown to head transformation
#   raw_14.set_montage(custom_montage_14)
# <ipython-input-12-d246b76a61e6>:9: RuntimeWarning: Fiducial point nasion not found, assuming identity unknown to head transformation
#   custom_montage_14.plot()

# %%
# Create a sample Raw data object with these channels
info_32 = mne.create_info(ch_names=eeg_channel_32, sfreq=256, ch_types='eeg')
raw_32 = mne.io.RawArray(np.zeros((32, 1)), info_32)

# Apply the custom montage to the Raw object
raw_32.set_montage(custom_montage_32)

# Visualize the electrode layout
custom_montage_32.plot()
# Out:
# Creating RawArray with float64 data, n_channels=32, n_times=1
#     Range : 0 ... 0 =      0.000 ...     0.000 secs
# Ready.
# <ipython-input-13-54d3ddae08ad>:6: RuntimeWarning: Fiducial point nasion not found, assuming identity unknown to head transformation
#   raw_32.set_montage(custom_montage_32)
# <ipython-input-13-54d3ddae08ad>:9: RuntimeWarning: Fiducial point nasion not found, assuming identity unknown to head transformation
#   custom_montage_32.plot()

# %%
# thresh_valence = np.median(label_training[:,0])
# thresh_arousal = np.median(label_training[:,1])
# print(thresh_valence, thresh_arousal)

thresh_valence = 5.0
thresh_arousal = 5.0

# %%
count = [0,0,0,0]

for row in label_training:

    if row[0] > thresh_valence and row[1] > thresh_arousal:
      count[0] += 1

    elif row[0] < thresh_valence and row[1] > thresh_arousal:
      count[1] += 1

    elif row[0] > thresh_valence and row[1] < thresh_arousal:
      count[2] += 1

    elif row[0] < thresh_valence and row[1] < thresh_arousal:
      count[3] += 1

# Define the English labels for each emotion category
emotion_labels = [

    "HVHA", #High Valance High Arousal
    "LVHA", #Low Valance High Arousal
    "HVLA", #High Valance Low Arousal
    "LVLA" #Low Valance Low Arousal
]

# Print the count for each emotion category
for i, count_value in enumerate(count):
    print(f"Count for {emotion_labels[i]}: {count_value}")
# Out:
# Count for HVHA: 49184
# Count for LVHA: 29279
# Count for HVLA: 37089
# Count for LVLA: 38265

# %%
# Classify points into 4 categories based on valence and arousal thresholds
HVHA = label_training[(label_training[:, 0] > thresh_valence) & (label_training[:, 1] > thresh_arousal)]
LVHA = label_training[(label_training[:, 0] < thresh_valence) & (label_training[:, 1] > thresh_arousal)]
HVLA = label_training[(label_training[:, 0] > thresh_valence) & (label_training[:, 1] < thresh_arousal)]
LVLA = label_training[(label_training[:, 0] < thresh_valence) & (label_training[:, 1] < thresh_arousal)]

# Set the figure resolution
plt.figure(dpi=300)

# Plotting with updated marker styles and colors
plt.scatter(HVHA[:, 1], HVHA[:, 0], s=25, color='#FF9999', label="HVHA", edgecolor='#505050', linewidth=0.3, alpha=0.7, marker='o')
plt.scatter(LVHA[:, 1], LVHA[:, 0], s=25, color='#9999FF', label="LVHA", edgecolor='#505050', linewidth=0.3, alpha=0.7, marker='o')
plt.scatter(HVLA[:, 1], HVLA[:, 0], s=25, color='#99FF99', label="HVLA", edgecolor='#505050', linewidth=0.3, alpha=0.7, marker='o')
plt.scatter(LVLA[:, 1], LVLA[:, 0], s=25, color='#FFFF66', label="LVLA", edgecolor='#505050', linewidth=0.3, alpha=0.7, marker='o')

# Adding crosshairs for thresholds
plt.axhline(thresh_valence, color='black', linestyle='--')
plt.axvline(thresh_arousal, color='black', linestyle='--')

# Adding labels, title, and legend
plt.xlabel('Arousal')
plt.ylabel('Valence')
plt.title('Label Classification by Valence and Arousal')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # DATASET PREPARATION

# %%
def z_score(data):
  data_mean = np.mean(data, axis=1)
  data_stds = np.std(data, axis=1)
  normalized_data = (data - data_mean[:, np.newaxis]) / data_stds[:, np.newaxis]
  return normalized_data

def min_max_scaling(data):
  data_min = np.min(data, axis=1, keepdims=True)
  data_max = np.max(data, axis=1, keepdims=True)
  normalized_data = (data - data_min) / (data_max - data_min)
  return normalized_data

# %%
from torchvision import transforms

class EEGDataset(Dataset):
  def __init__(self, data, labels, thresh_valence, thresh_arousal):
    self.data           = data
    self.labels         = labels
    self.thresh_valence = thresh_valence
    self.thresh_arousal = thresh_arousal

    self.transform = transforms.Compose([
                                transforms.ToTensor(),
                        ])

  def __getitem__(self, index):
    data = self.data[index]
    # print(data.shape)

    #data = z_score(data)
    #data = min_max_scaling(data)
    data = self.transform(data)

    label = self.labels[index]

    if label[0] > self.thresh_valence and label[1] > self.thresh_arousal:
      return data, torch.tensor([1,0,0,0])

    elif label[0] < self.thresh_valence and label[1] > self.thresh_arousal:
      return data, torch.tensor([0,1,0,0])

    elif label[0] > self.thresh_valence and label[1] < self.thresh_arousal:
      return data, torch.tensor([0,0,1,0])

    elif label[0] < self.thresh_valence and label[1] < self.thresh_arousal:
      return data, torch.tensor([0,0,0,1])
    else:
      return data, torch.tensor([1,0,0,0])

  def __len__(self):
    return len(self.data)

# %%
train_eeg_dataset = EEGDataset(data_training, label_training, thresh_valence, thresh_arousal)
test_eeg_dataset  = EEGDataset(data_testing, label_testing, thresh_valence, thresh_arousal)

print(len(train_eeg_dataset))
d, l = train_eeg_dataset[0]
print(d.shape)
print(l)
# Out:
# 156160
# torch.Size([1, 14, 256])
# tensor([1, 0, 0, 0])

# %%
if data_type == 'RAW':
  num_channels = d.shape[1]  # Total number of channels
  num_channels_visual = 3
  first_channels = range(num_channels_visual)

  # Setting up the plot
  fig, axes = plt.subplots(nrows=num_channels_visual, ncols=1, figsize=(10, 5))
  fig.suptitle('DATA_RAW_EPOCH')

  # Plotting the first three channels
  for i, channel in enumerate(first_channels):
      axes[i].plot(d[0][channel].detach().numpy())
      #axes[i].set_title(f'Channel {channel+1}')
      axes[i].set_xlabel('TIME_POINTS')
      axes[i].set_ylabel(f'Channel{channel+1}')

else:
  plt.figure(figsize=(10, 5))
  plt.plot(d[0][0].detach().numpy())
  plt.title('DATA_FFT_EPOCH')  # Add a title to the plot
  plt.xlabel('TIME_POINTS')  # Optionally, label the x-axis
  plt.ylabel('FEATURE')  # Optionally, label the y-axis
  plt.show()  # Display the plot

# %%
train_eeg_dataloader = DataLoader(train_eeg_dataset,batch_size= 256,shuffle=True, num_workers=2)
test_eeg_dataloader = DataLoader(test_eeg_dataset,batch_size= 256, shuffle=False, num_workers=2)

# Display the shape of data and labels in the training set
train_data_sample, train_label_sample = train_eeg_dataset[0]
print("Training Data Sample Shape:", train_data_sample.shape)
print("Training Label Sample Shape:", train_label_sample.shape)

# Display the shape of data and labels in the testing set
test_data_sample, test_label_sample = test_eeg_dataset[0]
print("Testing Data Sample Shape:", test_data_sample.shape)
print("Testing Label Sample Shape:", test_label_sample.shape)
# Out:
# Training Data Sample Shape: torch.Size([1, 14, 256])
# Training Label Sample Shape: torch.Size([4])
# Testing Data Sample Shape: torch.Size([1, 14, 256])
# Testing Label Sample Shape: torch.Size([4])

# %% [markdown]
# # MODEL DEFINITION

# %%
import torch
import torch.nn as nn

class CNN1D_LSTM(nn.Module):
    def __init__(self, num_classes):
        super(CNN1D_LSTM, self).__init__()

        # Define the 1D convolutional layers
        self.convs = nn.Sequential(
            nn.Conv1d(14, 1024, kernel_size=75, stride=1, padding='same'),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Dropout(p=0.2),

            nn.Conv1d(1024, 512, kernel_size=50, stride=1, padding='same'),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Dropout(p=0.2),

            nn.Conv1d(512, 256, kernel_size=25, stride=1, padding='same'),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Dropout(p=0.2),
        )

        self.lstm1 = nn.LSTM(input_size=256, hidden_size=256, batch_first=True)
        self.lstm2 = nn.LSTM(input_size=256, hidden_size=128, batch_first=True)

        # Fully connected layers
        self.fc_input_size = 32*128  # Hidden_size of LSTM
        self.linears = nn.Sequential(
            nn.Linear(self.fc_input_size, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes),
            nn.Softmax(dim=1)
        )

    def forward(self, x):

        # Convolution layers
        x = self.convs(x)
        #print("After conv layers: ", x.shape)  # Print the shape after convolution layers

        # Reshaping for LSTM layer
        x = x.permute(0, 2, 1)
        #print("Before LSTM layers: ", x.shape)  # Print the shape before LSTM layers

        # LSTM layers
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        #print("After LSTM layer: ", x.shape)  # Print the shape after the second LSTM layer

        # Flatten the output for the linear layers
        x = x.reshape(x.shape[0], -1)  # Flatten
        #print("Before linear layers: ", x.shape)  # Print the shape before linear layers

        x = self.linears(x)

        return x

    def count_parameters(model):
      return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Instantiate the model
model = CNN1D_LSTM(num_classes=4)


# Print the model architecture
print(model)
print(f"Total trainable parameters: {model.count_parameters()}")
# Out:
# CNN1D_LSTM(
#   (convs): Sequential(
#     (0): Conv1d(14, 1024, kernel_size=(75,), stride=(1,), padding=same)
#     (1): ReLU()
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Conv1d(1024, 512, kernel_size=(50,), stride=(1,), padding=same)
#     (5): ReLU()
#     (6): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv1d(512, 256, kernel_size=(25,), stride=(1,), padding=same)
#     (9): ReLU()
#     (10): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Dropout(p=0.2, inplace=False)
#   )
#   (lstm1): LSTM(256, 256, batch_first=True)
#   (lstm2): LSTM(256, 128, batch_first=True)
#   (linears): Sequential(
#     (0): Linear(in_features=4096, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=4, bias=True)
#     (7): Softmax(dim=1)
#   )
# )
# Total trainable parameters: 32382404

# %%
import torch
import torch.nn as nn

class CNN1D_LSTM_FFT(nn.Module):
    def __init__(self, num_classes):
        super(CNN1D_LSTM_FFT, self).__init__()

        # Define the 1D convolutional layers
        # First Convolutional block
        self.convs = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=512, kernel_size=50, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Dropout(p=0.2),

            nn.Conv1d(in_channels=512, out_channels=256, kernel_size=25, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Dropout(p=0.2),

        )

        self.lstm1 = nn.LSTM(input_size=256, hidden_size=256, batch_first=True)
        self.lstm2 = nn.LSTM(input_size=256, hidden_size=128, batch_first=True)

        # Fully connected layers
        self.fc_input_size = 17*128  # Hidden_size of LSTM
        self.linears = nn.Sequential(
            nn.Linear(self.fc_input_size, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes),
            nn.Softmax(dim=1)
        )

    def forward(self, x):

        # Convolution layers
        x = self.convs(x)
        #print("After conv layers: ", x.shape)  # Print the shape after convolution layers

        # Reshaping for LSTM layer
        #x = x.unsqueeze(0)
        x = x.permute(0,2,1)
        #print("Before LSTM layers: ", x.shape)  # Print the shape before LSTM layers

        # LSTM layers
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        #print("After LSTM layer: ", x.shape)  # Print the shape after the second LSTM layer

        # Flatten the output for the linear layers
        x = x.reshape(x.shape[0], -1)  # Flatten
        #print("Before linear layers: ", x.shape)  # Print the shape before linear layers

        x = self.linears(x)

        return x

    def count_parameters(model):
      return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Instantiate the model
model = CNN1D_LSTM_FFT(num_classes=4)

# Print the model architecture
print(model)
print(f"Total trainable parameters: {model.count_parameters()}")
# Out:
# CNN1D_LSTM_FFT(
#   (convs): Sequential(
#     (0): Conv1d(1, 512, kernel_size=(50,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Conv1d(512, 256, kernel_size=(25,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (lstm1): LSTM(256, 256, batch_first=True)
#   (lstm2): LSTM(256, 128, batch_first=True)
#   (linears): Sequential(
#     (0): Linear(in_features=2176, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=4, bias=True)
#     (7): Softmax(dim=1)
#   )
# )
# Total trainable parameters: 4625860

# %% [markdown]
# # MODEL TRAINING

# %%
if data_type =='FFT':
  model = CNN1D_LSTM_FFT(num_classes=4)
  model_train = "CNN1D_LSTM_FFT"
  print("FFT Training")

else:
  model = CNN1D_LSTM(num_classes=4)
  model_train = "CNN1D_LSTM"
  print("RAW Training")
# Out:
# RAW Training

# %%
# Test sample
model.to(device)
id = 1
data_p, label_p = test_eeg_dataset[id]
data_p = data_p.to(device).float()
label_p = label_p.float().to(device)

# Make predictions
yhat = model.forward(data_p.to(device)).float()

print(label_p)
print(yhat)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:306: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:1008.)
#   return F.conv1d(input, weight, bias, self.stride,
# tensor([1., 0., 0., 0.], device='cuda:0')
# tensor([[0.2745, 0.2351, 0.2161, 0.2743]], device='cuda:0',
#        grad_fn=<SoftmaxBackward0>)

# %%
EPOCHS  = 100
results = {'loss': [], 'val_loss': [], 'auc': [], 'val_auc': []}
optim   = torch.optim.Adam(model.parameters(), lr=1e-5, weight_decay=1e-3)
loss    = nn.CrossEntropyLoss()
# Early Stopping
patience = 10
patience_counter = 0
best_val_loss = float('inf')
best_val_acc = 0
best_model_state = None

# %%
model.to(device)
total_data = len(train_eeg_dataloader)
for epoch in range(EPOCHS):
    # ------training------
    epoch_losses = []
    epoch_aucs = []
    model.train()
    for idx, (x, y) in enumerate(train_eeg_dataloader):
        x    = x.squeeze(1).to(torch.float)
        yhat = model.forward(x.to(device)).float()    # Find predicted
        y    = y.float().to(device)                   # label to device
        out  = loss(yhat, y)                          # find loss between predicted and label

        # accuracy
        labels  = torch.argmax(y,dim=1)
        pred    = torch.argmax(yhat,dim=1)
        correct = (labels == pred).sum().item()
        epoch_aucs.append(correct)


        # Backpropagation step
        optim.zero_grad()
        out.backward()
        optim.step()

        epoch_losses.append(out.item())

        if (idx+1) % 50 == 0:
          print("Epoch: {}/{}\t batch: {}/{}\tTrain Loss: {:.4f}\t".format(epoch+1, EPOCHS, idx+1, total_data,out.item()) )


    epoch_loss = np.mean(epoch_losses)
    epoch_auc = np.sum(epoch_aucs) / len(train_eeg_dataset)

    # -----validation-----
    model.eval()
    epoch_val_losses = []
    epoch_val_aucs = []
    with torch.no_grad():
        for x, y in test_eeg_dataloader:
            x    = x.squeeze(1)
            x    = x.to(torch.float)
            yhat = model.forward(x.to(device)).float() # Find predicted
            y    = y.float().to(device)                   # label to device
            out  = loss(yhat, y)
            epoch_val_losses.append(out.item())

            # accuracy
            gt      = torch.argmax(y,dim=1)
            pred    = torch.argmax(yhat,dim=1)
            correct = (gt == pred).sum().item()
            epoch_val_aucs.append(correct)


    epoch_val_loss = np.mean(epoch_val_losses)
    epoch_val_auc  = np.sum(epoch_val_aucs) / len(test_eeg_dataset)


    # populate results
    results['loss'].append( epoch_loss )
    results['val_loss'].append( epoch_val_loss )
    results['auc'].append( epoch_auc )
    results['val_auc'].append( epoch_val_auc )

    if best_val_acc < epoch_val_auc:
      best_val_acc = epoch_val_auc
      best_model_state = model.state_dict()

    if epoch_val_loss < best_val_loss:
      best_val_loss = epoch_val_loss
      patience_counter = 0
    else:
      patience_counter += 1

    print("\nEpoch {}/{}\tTrain Loss: {:.4f}\tTest Loss: {:.4f}\tTrain Acc: {:.4f}\tTest Acc: {:.4f}\tBest Acc: {:.4f}\n".format(
          epoch+1, EPOCHS, epoch_loss, epoch_val_loss, epoch_auc, epoch_val_auc,best_val_acc) )

    # Early Stopping
    if patience_counter >= patience:
      print("Early stopping triggered. Training stopped.")
      break
# Out:
# Epoch: 1/100	 batch: 50/610	Train Loss: 1.3805
# Epoch: 1/100	 batch: 100/610	Train Loss: 1.3734
# Epoch: 1/100	 batch: 150/610	Train Loss: 1.3663
# Epoch: 1/100	 batch: 200/610	Train Loss: 1.3737
# Epoch: 1/100	 batch: 250/610	Train Loss: 1.3495
# Epoch: 1/100	 batch: 300/610	Train Loss: 1.3418
# Epoch: 1/100	 batch: 350/610	Train Loss: 1.3511
# Epoch: 1/100	 batch: 400/610	Train Loss: 1.3483
# Epoch: 1/100	 batch: 450/610	Train Loss: 1.3054
# Epoch: 1/100	 batch: 500/610	Train Loss: 1.3010
# Epoch: 1/100	 batch: 550/610	Train Loss: 1.3140
# Epoch: 1/100	 batch: 600/610	Train Loss: 1.3317
#
# Epoch 1/100	Train Loss: 1.3495	Test Loss: 1.3088	Train Acc: 0.3576	Test Acc: 0.4101	Best Acc: 0.4101
#
# Epoch: 2/100	 batch: 50/610	Train Loss: 1.3241
# Epoch: 2/100	 batch: 100/610	Train Loss: 1.3048
# Epoch: 2/100	 batch: 150/610	Train Loss: 1.3014
# Epoch: 2/100	 batch: 200/610	Train Loss: 1.2706
# Epoch: 2/100	 batch: 250/610	Train Loss: 1.2849
# Epoch: 2/100	 batch: 300/610	Train Loss: 1.2524
# Epoch: 2/100	 batch: 350/610	Train Loss: 1.2318
# Epoch: 2/100	 batch: 400/610	Train Loss: 1.2985
# Epoch: 2/100	 batch: 450/610	Train Loss: 1.2286
# Epoch: 2/100	 batch: 500/610	Train Loss: 1.2654
# Epoch: 2/100	 batch: 550/610	Train Loss: 1.2505
# Epoch: 2/100	 batch: 600/610	Train Loss: 1.2829
#
# Epoch 2/100	Train Loss: 1.2919	Test Loss: 1.2625	Train Acc: 0.4352	Test Acc: 0.4690	Best Acc: 0.4690
#
# Epoch: 3/100	 batch: 50/610	Train Loss: 1.2649
# Epoch: 3/100	 batch: 100/610	Train Loss: 1.2878
# Epoch: 3/100	 batch: 150/610	Train Loss: 1.2515
# Epoch: 3/100	 batch: 200/610	Train Loss: 1.2873
# Epoch: 3/100	 batch: 250/610	Train Loss: 1.2702
# Epoch: 3/100	 batch: 300/610	Train Loss: 1.2391
# Epoch: 3/100	 batch: 350/610	Train Loss: 1.2474
# Epoch: 3/100	 batch: 400/610	Train Loss: 1.2253
# Epoch: 3/100	 batch: 450/610	Train Loss: 1.2618
# Epoch: 3/100	 batch: 500/610	Train Loss: 1.2561
# Epoch: 3/100	 batch: 550/610	Train Loss: 1.2374
# Epoch: 3/100	 batch: 600/610	Train Loss: 1.2332
#
# Epoch 3/100	Train Loss: 1.2562	Test Loss: 1.2628	Train Acc: 0.4721	Test Acc: 0.4555	Best Acc: 0.4690
#
# Epoch: 4/100	 batch: 50/610	Train Loss: 1.2363
# Epoch: 4/100	 batch: 100/610	Train Loss: 1.2341
# Epoch: 4/100	 batch: 150/610	Train Loss: 1.2090
# Epoch: 4/100	 batch: 200/610	Train Loss: 1.2468
# Epoch: 4/100	 batch: 250/610	Train Loss: 1.2033
# Epoch: 4/100	 batch: 300/610	Train Loss: 1.2480
# Epoch: 4/100	 batch: 350/610	Train Loss: 1.2205
# Epoch: 4/100	 batch: 400/610	Train Loss: 1.2281
# Epoch: 4/100	 batch: 450/610	Train Loss: 1.2682
# Epoch: 4/100	 batch: 500/610	Train Loss: 1.1851
# Epoch: 4/100	 batch: 550/610	Train Loss: 1.2595
# Epoch: 4/100	 batch: 600/610	Train Loss: 1.2084
#
# Epoch 4/100	Train Loss: 1.2391	Test Loss: 1.2204	Train Acc: 0.4880	Test Acc: 0.5092	Best Acc: 0.5092
#
# Epoch: 5/100	 batch: 50/610	Train Loss: 1.2133
# Epoch: 5/100	 batch: 100/610	Train Loss: 1.2449
# Epoch: 5/100	 batch: 150/610	Train Loss: 1.2169
# Epoch: 5/100	 batch: 200/610	Train Loss: 1.1876
# Epoch: 5/100	 batch: 250/610	Train Loss: 1.2960
# Epoch: 5/100	 batch: 300/610	Train Loss: 1.2336
# Epoch: 5/100	 batch: 350/610	Train Loss: 1.2034
# Epoch: 5/100	 batch: 400/610	Train Loss: 1.2187
# Epoch: 5/100	 batch: 450/610	Train Loss: 1.1769
# Epoch: 5/100	 batch: 500/610	Train Loss: 1.1691
# Epoch: 5/100	 batch: 550/610	Train Loss: 1.2432
# Epoch: 5/100	 batch: 600/610	Train Loss: 1.1763
#
# Epoch 5/100	Train Loss: 1.2208	Test Loss: 1.2459	Train Acc: 0.5089	Test Acc: 0.4786	Best Acc: 0.5092
#
# Epoch: 6/100	 batch: 50/610	Train Loss: 1.1886
# Epoch: 6/100	 batch: 100/610	Train Loss: 1.2157
# Epoch: 6/100	 batch: 150/610	Train Loss: 1.2225
# Epoch: 6/100	 batch: 200/610	Train Loss: 1.1705
# Epoch: 6/100	 batch: 250/610	Train Loss: 1.2433
# Epoch: 6/100	 batch: 300/610	Train Loss: 1.2126
# Epoch: 6/100	 batch: 350/610	Train Loss: 1.1690
# Epoch: 6/100	 batch: 400/610	Train Loss: 1.2132
# Epoch: 6/100	 batch: 450/610	Train Loss: 1.2331
# Epoch: 6/100	 batch: 500/610	Train Loss: 1.1839
# Epoch: 6/100	 batch: 550/610	Train Loss: 1.2480
# Epoch: 6/100	 batch: 600/610	Train Loss: 1.1820
#
# Epoch 6/100	Train Loss: 1.2055	Test Loss: 1.1796	Train Acc: 0.5248	Test Acc: 0.5539	Best Acc: 0.5539
#
# Epoch: 7/100	 batch: 50/610	Train Loss: 1.2368
# Epoch: 7/100	 batch: 100/610	Train Loss: 1.2242
# Epoch: 7/100	 batch: 150/610	Train Loss: 1.1929
# Epoch: 7/100	 batch: 200/610	Train Loss: 1.1856
# Epoch: 7/100	 batch: 250/610	Train Loss: 1.2272
# Epoch: 7/100	 batch: 300/610	Train Loss: 1.1704
# Epoch: 7/100	 batch: 350/610	Train Loss: 1.1917
# Epoch: 7/100	 batch: 400/610	Train Loss: 1.1724
# Epoch: 7/100	 batch: 450/610	Train Loss: 1.1646
# Epoch: 7/100	 batch: 500/610	Train Loss: 1.1801
# Epoch: 7/100	 batch: 550/610	Train Loss: 1.1669
# Epoch: 7/100	 batch: 600/610	Train Loss: 1.1843
#
# Epoch 7/100	Train Loss: 1.1844	Test Loss: 1.1771	Train Acc: 0.5492	Test Acc: 0.5575	Best Acc: 0.5575
#
# Epoch: 8/100	 batch: 50/610	Train Loss: 1.1307
# Epoch: 8/100	 batch: 100/610	Train Loss: 1.1498
# Epoch: 8/100	 batch: 150/610	Train Loss: 1.1546
# Epoch: 8/100	 batch: 200/610	Train Loss: 1.2049
# Epoch: 8/100	 batch: 250/610	Train Loss: 1.1739
# Epoch: 8/100	 batch: 300/610	Train Loss: 1.1790
# Epoch: 8/100	 batch: 350/610	Train Loss: 1.1501
# Epoch: 8/100	 batch: 400/610	Train Loss: 1.1831
# Epoch: 8/100	 batch: 450/610	Train Loss: 1.1553
# Epoch: 8/100	 batch: 500/610	Train Loss: 1.1610
# Epoch: 8/100	 batch: 550/610	Train Loss: 1.1513
# Epoch: 8/100	 batch: 600/610	Train Loss: 1.1375
#
# Epoch 8/100	Train Loss: 1.1685	Test Loss: 1.1507	Train Acc: 0.5659	Test Acc: 0.5872	Best Acc: 0.5872
#
# Epoch: 9/100	 batch: 50/610	Train Loss: 1.1129
# Epoch: 9/100	 batch: 100/610	Train Loss: 1.1280
# Epoch: 9/100	 batch: 150/610	Train Loss: 1.1971
# Epoch: 9/100	 batch: 200/610	Train Loss: 1.1651
# Epoch: 9/100	 batch: 250/610	Train Loss: 1.1976
# Epoch: 9/100	 batch: 300/610	Train Loss: 1.2235
# Epoch: 9/100	 batch: 350/610	Train Loss: 1.1682
# Epoch: 9/100	 batch: 400/610	Train Loss: 1.1161
# Epoch: 9/100	 batch: 450/610	Train Loss: 1.1535
# Epoch: 9/100	 batch: 500/610	Train Loss: 1.0969
# Epoch: 9/100	 batch: 550/610	Train Loss: 1.1620
# Epoch: 9/100	 batch: 600/610	Train Loss: 1.1500
#
# Epoch 9/100	Train Loss: 1.1560	Test Loss: 1.1307	Train Acc: 0.5796	Test Acc: 0.6073	Best Acc: 0.6073
#
# Epoch: 10/100	 batch: 50/610	Train Loss: 1.1248
# Epoch: 10/100	 batch: 100/610	Train Loss: 1.1198
# Epoch: 10/100	 batch: 150/610	Train Loss: 1.1313
# Epoch: 10/100	 batch: 200/610	Train Loss: 1.1511
# Epoch: 10/100	 batch: 250/610	Train Loss: 1.1207
# Epoch: 10/100	 batch: 300/610	Train Loss: 1.1320
# Epoch: 10/100	 batch: 350/610	Train Loss: 1.1547
# Epoch: 10/100	 batch: 400/610	Train Loss: 1.1561
# Epoch: 10/100	 batch: 450/610	Train Loss: 1.1227
# Epoch: 10/100	 batch: 500/610	Train Loss: 1.1322
# Epoch: 10/100	 batch: 550/610	Train Loss: 1.1480
# Epoch: 10/100	 batch: 600/610	Train Loss: 1.0754
#
# Epoch 10/100	Train Loss: 1.1354	Test Loss: 1.1175	Train Acc: 0.6024	Test Acc: 0.6219	Best Acc: 0.6219
#
# Epoch: 11/100	 batch: 50/610	Train Loss: 1.1059
# Epoch: 11/100	 batch: 100/610	Train Loss: 1.1163
# Epoch: 11/100	 batch: 150/610	Train Loss: 1.0988
# Epoch: 11/100	 batch: 200/610	Train Loss: 1.1428
# Epoch: 11/100	 batch: 250/610	Train Loss: 1.1353
# Epoch: 11/100	 batch: 300/610	Train Loss: 1.0639
# Epoch: 11/100	 batch: 350/610	Train Loss: 1.1514
# Epoch: 11/100	 batch: 400/610	Train Loss: 1.1468
# Epoch: 11/100	 batch: 450/610	Train Loss: 1.0874
# Epoch: 11/100	 batch: 500/610	Train Loss: 1.1151
# Epoch: 11/100	 batch: 550/610	Train Loss: 1.1722
# Epoch: 11/100	 batch: 600/610	Train Loss: 1.1181
#
# Epoch 11/100	Train Loss: 1.1250	Test Loss: 1.0939	Train Acc: 0.6131	Test Acc: 0.6474	Best Acc: 0.6474
#
# Epoch: 12/100	 batch: 50/610	Train Loss: 1.0353
# Epoch: 12/100	 batch: 100/610	Train Loss: 1.1321
# Epoch: 12/100	 batch: 150/610	Train Loss: 1.1327
# Epoch: 12/100	 batch: 200/610	Train Loss: 1.2043
# Epoch: 12/100	 batch: 250/610	Train Loss: 1.0879
# Epoch: 12/100	 batch: 300/610	Train Loss: 1.0935
# Epoch: 12/100	 batch: 350/610	Train Loss: 1.0740
# Epoch: 12/100	 batch: 400/610	Train Loss: 1.0998
# Epoch: 12/100	 batch: 450/610	Train Loss: 1.1749
# Epoch: 12/100	 batch: 500/610	Train Loss: 1.0374
# Epoch: 12/100	 batch: 550/610	Train Loss: 1.1256
# Epoch: 12/100	 batch: 600/610	Train Loss: 1.1234
#
# Epoch 12/100	Train Loss: 1.1095	Test Loss: 1.0730	Train Acc: 0.6302	Test Acc: 0.6700	Best Acc: 0.6700
#
# Epoch: 13/100	 batch: 50/610	Train Loss: 1.0797
# Epoch: 13/100	 batch: 100/610	Train Loss: 1.1050
# Epoch: 13/100	 batch: 150/610	Train Loss: 1.1024
# Epoch: 13/100	 batch: 200/610	Train Loss: 1.0641
# Epoch: 13/100	 batch: 250/610	Train Loss: 1.0513
# Epoch: 13/100	 batch: 300/610	Train Loss: 1.1099
# Epoch: 13/100	 batch: 350/610	Train Loss: 1.0429
# Epoch: 13/100	 batch: 400/610	Train Loss: 1.0903
# Epoch: 13/100	 batch: 450/610	Train Loss: 1.0746
# Epoch: 13/100	 batch: 500/610	Train Loss: 1.1192
# Epoch: 13/100	 batch: 550/610	Train Loss: 1.1037
# Epoch: 13/100	 batch: 600/610	Train Loss: 1.0509
#
# Epoch 13/100	Train Loss: 1.0975	Test Loss: 1.0576	Train Acc: 0.6424	Test Acc: 0.6845	Best Acc: 0.6845
#
# Epoch: 14/100	 batch: 50/610	Train Loss: 1.0426
# Epoch: 14/100	 batch: 100/610	Train Loss: 1.1114
# Epoch: 14/100	 batch: 150/610	Train Loss: 1.0914
# Epoch: 14/100	 batch: 200/610	Train Loss: 1.1970
# Epoch: 14/100	 batch: 250/610	Train Loss: 1.0882
# Epoch: 14/100	 batch: 300/610	Train Loss: 1.0622
# Epoch: 14/100	 batch: 350/610	Train Loss: 1.1345
# Epoch: 14/100	 batch: 400/610	Train Loss: 1.0785
# Epoch: 14/100	 batch: 450/610	Train Loss: 1.0308
# Epoch: 14/100	 batch: 500/610	Train Loss: 1.1043
# Epoch: 14/100	 batch: 550/610	Train Loss: 1.0797
# Epoch: 14/100	 batch: 600/610	Train Loss: 1.0562
#
# Epoch 14/100	Train Loss: 1.0899	Test Loss: 1.0939	Train Acc: 0.6497	Test Acc: 0.6423	Best Acc: 0.6845
#
# Epoch: 15/100	 batch: 50/610	Train Loss: 1.0541
# Epoch: 15/100	 batch: 100/610	Train Loss: 1.0894
# Epoch: 15/100	 batch: 150/610	Train Loss: 1.0971
# Epoch: 15/100	 batch: 200/610	Train Loss: 1.0711
# Epoch: 15/100	 batch: 250/610	Train Loss: 1.0467
# Epoch: 15/100	 batch: 300/610	Train Loss: 1.1073
# Epoch: 15/100	 batch: 350/610	Train Loss: 1.1065
# Epoch: 15/100	 batch: 400/610	Train Loss: 1.0246
# Epoch: 15/100	 batch: 450/610	Train Loss: 1.0622
# Epoch: 15/100	 batch: 500/610	Train Loss: 1.0988
# Epoch: 15/100	 batch: 550/610	Train Loss: 1.1367
# Epoch: 15/100	 batch: 600/610	Train Loss: 1.0697
#
# Epoch 15/100	Train Loss: 1.0737	Test Loss: 1.0391	Train Acc: 0.6670	Test Acc: 0.7032	Best Acc: 0.7032
#
# Epoch: 16/100	 batch: 50/610	Train Loss: 1.0625
# Epoch: 16/100	 batch: 100/610	Train Loss: 1.0393
# Epoch: 16/100	 batch: 150/610	Train Loss: 1.0629
# Epoch: 16/100	 batch: 200/610	Train Loss: 1.0813
# Epoch: 16/100	 batch: 250/610	Train Loss: 1.0853
# Epoch: 16/100	 batch: 300/610	Train Loss: 1.0483
# Epoch: 16/100	 batch: 350/610	Train Loss: 1.0755
# Epoch: 16/100	 batch: 400/610	Train Loss: 1.0303
# Epoch: 16/100	 batch: 450/610	Train Loss: 1.0641
# Epoch: 16/100	 batch: 500/610	Train Loss: 1.0542
# Epoch: 16/100	 batch: 550/610	Train Loss: 1.0749
# Epoch: 16/100	 batch: 600/610	Train Loss: 1.0661
#
# Epoch 16/100	Train Loss: 1.0650	Test Loss: 1.0811	Train Acc: 0.6761	Test Acc: 0.6600	Best Acc: 0.7032
#
# Epoch: 17/100	 batch: 50/610	Train Loss: 1.0722
# Epoch: 17/100	 batch: 100/610	Train Loss: 1.0549
# Epoch: 17/100	 batch: 150/610	Train Loss: 1.0544
# Epoch: 17/100	 batch: 200/610	Train Loss: 1.0634
# Epoch: 17/100	 batch: 250/610	Train Loss: 1.0051
# Epoch: 17/100	 batch: 300/610	Train Loss: 1.0638
# Epoch: 17/100	 batch: 350/610	Train Loss: 1.0677
# Epoch: 17/100	 batch: 400/610	Train Loss: 1.0616
# Epoch: 17/100	 batch: 450/610	Train Loss: 1.0182
# Epoch: 17/100	 batch: 500/610	Train Loss: 1.0123
# Epoch: 17/100	 batch: 550/610	Train Loss: 1.1053
# Epoch: 17/100	 batch: 600/610	Train Loss: 1.0691
#
# Epoch 17/100	Train Loss: 1.0601	Test Loss: 1.0538	Train Acc: 0.6804	Test Acc: 0.6881	Best Acc: 0.7032
#
# Epoch: 18/100	 batch: 50/610	Train Loss: 1.0462
# Epoch: 18/100	 batch: 100/610	Train Loss: 1.0289
# Epoch: 18/100	 batch: 150/610	Train Loss: 1.0328
# Epoch: 18/100	 batch: 200/610	Train Loss: 1.0417
# Epoch: 18/100	 batch: 250/610	Train Loss: 0.9948
# Epoch: 18/100	 batch: 300/610	Train Loss: 1.0848
# Epoch: 18/100	 batch: 350/610	Train Loss: 0.9983
# Epoch: 18/100	 batch: 400/610	Train Loss: 1.0194
# Epoch: 18/100	 batch: 450/610	Train Loss: 1.0817
# Epoch: 18/100	 batch: 500/610	Train Loss: 0.9861
# Epoch: 18/100	 batch: 550/610	Train Loss: 1.0260
# Epoch: 18/100	 batch: 600/610	Train Loss: 1.0165
#
# Epoch 18/100	Train Loss: 1.0523	Test Loss: 1.0107	Train Acc: 0.6890	Test Acc: 0.7329	Best Acc: 0.7329
#
# Epoch: 19/100	 batch: 50/610	Train Loss: 0.9990
# Epoch: 19/100	 batch: 100/610	Train Loss: 1.0792
# Epoch: 19/100	 batch: 150/610	Train Loss: 1.0241
# Epoch: 19/100	 batch: 200/610	Train Loss: 1.0145
# Epoch: 19/100	 batch: 250/610	Train Loss: 1.0890
# Epoch: 19/100	 batch: 300/610	Train Loss: 1.0555
# Epoch: 19/100	 batch: 350/610	Train Loss: 1.0101
# Epoch: 19/100	 batch: 400/610	Train Loss: 1.0225
# Epoch: 19/100	 batch: 450/610	Train Loss: 1.0275
# Epoch: 19/100	 batch: 500/610	Train Loss: 1.0649
# Epoch: 19/100	 batch: 550/610	Train Loss: 1.0691
# Epoch: 19/100	 batch: 600/610	Train Loss: 1.0362
#
# Epoch 19/100	Train Loss: 1.0413	Test Loss: 1.0176	Train Acc: 0.7003	Test Acc: 0.7235	Best Acc: 0.7329
#
# Epoch: 20/100	 batch: 50/610	Train Loss: 1.0280
# Epoch: 20/100	 batch: 100/610	Train Loss: 1.0043
# Epoch: 20/100	 batch: 150/610	Train Loss: 1.0365
# Epoch: 20/100	 batch: 200/610	Train Loss: 1.0928
# Epoch: 20/100	 batch: 250/610	Train Loss: 1.0030
# Epoch: 20/100	 batch: 300/610	Train Loss: 1.0520
# Epoch: 20/100	 batch: 350/610	Train Loss: 1.0509
# Epoch: 20/100	 batch: 400/610	Train Loss: 1.0739
# Epoch: 20/100	 batch: 450/610	Train Loss: 1.0213
# Epoch: 20/100	 batch: 500/610	Train Loss: 0.9933
# Epoch: 20/100	 batch: 550/610	Train Loss: 1.0347
# Epoch: 20/100	 batch: 600/610	Train Loss: 1.0398
#
# Epoch 20/100	Train Loss: 1.0329	Test Loss: 1.0017	Train Acc: 0.7087	Test Acc: 0.7409	Best Acc: 0.7409
#
# Epoch: 21/100	 batch: 50/610	Train Loss: 1.0665
# Epoch: 21/100	 batch: 100/610	Train Loss: 1.0155
# Epoch: 21/100	 batch: 150/610	Train Loss: 1.0346
# Epoch: 21/100	 batch: 200/610	Train Loss: 1.0844
# Epoch: 21/100	 batch: 250/610	Train Loss: 1.0780
# Epoch: 21/100	 batch: 300/610	Train Loss: 1.0173
# Epoch: 21/100	 batch: 350/610	Train Loss: 1.0580
# Epoch: 21/100	 batch: 400/610	Train Loss: 1.0598
# Epoch: 21/100	 batch: 450/610	Train Loss: 1.0168
# Epoch: 21/100	 batch: 500/610	Train Loss: 1.0461
# Epoch: 21/100	 batch: 550/610	Train Loss: 1.0067
# Epoch: 21/100	 batch: 600/610	Train Loss: 1.0384
#
# Epoch 21/100	Train Loss: 1.0257	Test Loss: 0.9909	Train Acc: 0.7161	Test Acc: 0.7517	Best Acc: 0.7517
#
# Epoch: 22/100	 batch: 50/610	Train Loss: 0.9643
# Epoch: 22/100	 batch: 100/610	Train Loss: 1.0379
# Epoch: 22/100	 batch: 150/610	Train Loss: 1.0333
# Epoch: 22/100	 batch: 200/610	Train Loss: 1.0499
# Epoch: 22/100	 batch: 250/610	Train Loss: 1.0194
# Epoch: 22/100	 batch: 300/610	Train Loss: 1.0100
# Epoch: 22/100	 batch: 350/610	Train Loss: 1.0440
# Epoch: 22/100	 batch: 400/610	Train Loss: 0.9788
# Epoch: 22/100	 batch: 450/610	Train Loss: 1.0012
# Epoch: 22/100	 batch: 500/610	Train Loss: 1.0066
# Epoch: 22/100	 batch: 550/610	Train Loss: 0.9957
# Epoch: 22/100	 batch: 600/610	Train Loss: 1.0346
#
# Epoch 22/100	Train Loss: 1.0182	Test Loss: 0.9976	Train Acc: 0.7238	Test Acc: 0.7445	Best Acc: 0.7517
#
# Epoch: 23/100	 batch: 50/610	Train Loss: 1.0150
# Epoch: 23/100	 batch: 100/610	Train Loss: 0.9345
# Epoch: 23/100	 batch: 150/610	Train Loss: 1.0534
# Epoch: 23/100	 batch: 200/610	Train Loss: 1.0191
# Epoch: 23/100	 batch: 250/610	Train Loss: 1.0310
# Epoch: 23/100	 batch: 300/610	Train Loss: 0.9580
# Epoch: 23/100	 batch: 350/610	Train Loss: 1.0883
# Epoch: 23/100	 batch: 400/610	Train Loss: 1.0490
# Epoch: 23/100	 batch: 450/610	Train Loss: 0.9839
# Epoch: 23/100	 batch: 500/610	Train Loss: 1.0033
# Epoch: 23/100	 batch: 550/610	Train Loss: 0.9827
# Epoch: 23/100	 batch: 600/610	Train Loss: 0.9747
#
# Epoch 23/100	Train Loss: 1.0146	Test Loss: 1.0142	Train Acc: 0.7272	Test Acc: 0.7284	Best Acc: 0.7517
#
# Epoch: 24/100	 batch: 50/610	Train Loss: 1.0095
# Epoch: 24/100	 batch: 100/610	Train Loss: 0.9613
# Epoch: 24/100	 batch: 150/610	Train Loss: 1.0901
# Epoch: 24/100	 batch: 200/610	Train Loss: 1.0006
# Epoch: 24/100	 batch: 250/610	Train Loss: 1.0101
# Epoch: 24/100	 batch: 300/610	Train Loss: 0.9809
# Epoch: 24/100	 batch: 350/610	Train Loss: 0.9861
# Epoch: 24/100	 batch: 400/610	Train Loss: 0.9892
# Epoch: 24/100	 batch: 450/610	Train Loss: 0.9965
# Epoch: 24/100	 batch: 500/610	Train Loss: 0.9937
# Epoch: 24/100	 batch: 550/610	Train Loss: 0.9946
# Epoch: 24/100	 batch: 600/610	Train Loss: 1.0119
#
# Epoch 24/100	Train Loss: 1.0056	Test Loss: 0.9895	Train Acc: 0.7366	Test Acc: 0.7539	Best Acc: 0.7539
#
# Epoch: 25/100	 batch: 50/610	Train Loss: 1.0155
# Epoch: 25/100	 batch: 100/610	Train Loss: 0.9787
# Epoch: 25/100	 batch: 150/610	Train Loss: 1.0290
# Epoch: 25/100	 batch: 200/610	Train Loss: 1.0275
# Epoch: 25/100	 batch: 250/610	Train Loss: 1.0120
# Epoch: 25/100	 batch: 300/610	Train Loss: 1.0410
# Epoch: 25/100	 batch: 350/610	Train Loss: 0.9830
# Epoch: 25/100	 batch: 400/610	Train Loss: 0.9979
# Epoch: 25/100	 batch: 450/610	Train Loss: 1.0251
# Epoch: 25/100	 batch: 500/610	Train Loss: 1.0093
# Epoch: 25/100	 batch: 550/610	Train Loss: 0.9989
# Epoch: 25/100	 batch: 600/610	Train Loss: 0.9894
#
# Epoch 25/100	Train Loss: 1.0008	Test Loss: 0.9724	Train Acc: 0.7416	Test Acc: 0.7703	Best Acc: 0.7703
#
# Epoch: 26/100	 batch: 50/610	Train Loss: 1.0153
# Epoch: 26/100	 batch: 100/610	Train Loss: 1.0453
# Epoch: 26/100	 batch: 150/610	Train Loss: 0.9413
# Epoch: 26/100	 batch: 200/610	Train Loss: 1.0162
# Epoch: 26/100	 batch: 250/610	Train Loss: 1.0078
# Epoch: 26/100	 batch: 300/610	Train Loss: 0.9710
# Epoch: 26/100	 batch: 350/610	Train Loss: 1.0734
# Epoch: 26/100	 batch: 400/610	Train Loss: 1.0069
# Epoch: 26/100	 batch: 450/610	Train Loss: 1.0061
# Epoch: 26/100	 batch: 500/610	Train Loss: 0.9816
# Epoch: 26/100	 batch: 550/610	Train Loss: 1.0415
# Epoch: 26/100	 batch: 600/610	Train Loss: 1.0262
#
# Epoch 26/100	Train Loss: 0.9910	Test Loss: 0.9843	Train Acc: 0.7516	Test Acc: 0.7592	Best Acc: 0.7703
#
# Epoch: 27/100	 batch: 50/610	Train Loss: 1.0025
# Epoch: 27/100	 batch: 100/610	Train Loss: 0.9536
# Epoch: 27/100	 batch: 150/610	Train Loss: 0.9957
# Epoch: 27/100	 batch: 200/610	Train Loss: 0.9654
# Epoch: 27/100	 batch: 250/610	Train Loss: 1.0123
# Epoch: 27/100	 batch: 300/610	Train Loss: 0.9980
# Epoch: 27/100	 batch: 350/610	Train Loss: 1.0114
# Epoch: 27/100	 batch: 400/610	Train Loss: 1.0342
# Epoch: 27/100	 batch: 450/610	Train Loss: 0.9900
# Epoch: 27/100	 batch: 500/610	Train Loss: 0.9793
# Epoch: 27/100	 batch: 550/610	Train Loss: 1.0037
# Epoch: 27/100	 batch: 600/610	Train Loss: 1.0003
#
# Epoch 27/100	Train Loss: 0.9925	Test Loss: 0.9545	Train Acc: 0.7500	Test Acc: 0.7883	Best Acc: 0.7883
#
# Epoch: 28/100	 batch: 50/610	Train Loss: 0.9619
# Epoch: 28/100	 batch: 100/610	Train Loss: 0.9913
# Epoch: 28/100	 batch: 150/610	Train Loss: 0.9962
# Epoch: 28/100	 batch: 200/610	Train Loss: 1.0163
# Epoch: 28/100	 batch: 250/610	Train Loss: 1.0040
# Epoch: 28/100	 batch: 300/610	Train Loss: 0.9493
# Epoch: 28/100	 batch: 350/610	Train Loss: 0.9436
# Epoch: 28/100	 batch: 400/610	Train Loss: 1.0108
# Epoch: 28/100	 batch: 450/610	Train Loss: 0.9457
# Epoch: 28/100	 batch: 500/610	Train Loss: 0.9406
# Epoch: 28/100	 batch: 550/610	Train Loss: 0.9710
# Epoch: 28/100	 batch: 600/610	Train Loss: 0.9678
#
# Epoch 28/100	Train Loss: 0.9822	Test Loss: 0.9584	Train Acc: 0.7605	Test Acc: 0.7854	Best Acc: 0.7883
#
# Epoch: 29/100	 batch: 50/610	Train Loss: 0.9197
# Epoch: 29/100	 batch: 100/610	Train Loss: 0.9766
# Epoch: 29/100	 batch: 150/610	Train Loss: 0.9406
# Epoch: 29/100	 batch: 200/610	Train Loss: 0.9735
# Epoch: 29/100	 batch: 250/610	Train Loss: 0.9600
# Epoch: 29/100	 batch: 300/610	Train Loss: 0.9503
# Epoch: 29/100	 batch: 350/610	Train Loss: 0.9356
# Epoch: 29/100	 batch: 400/610	Train Loss: 1.0313
# Epoch: 29/100	 batch: 450/610	Train Loss: 0.9532
# Epoch: 29/100	 batch: 500/610	Train Loss: 0.9759
# Epoch: 29/100	 batch: 550/610	Train Loss: 0.9650
# Epoch: 29/100	 batch: 600/610	Train Loss: 0.9768
#
# Epoch 29/100	Train Loss: 0.9813	Test Loss: 0.9538	Train Acc: 0.7613	Test Acc: 0.7893	Best Acc: 0.7893
#
# Epoch: 30/100	 batch: 50/610	Train Loss: 0.9891
# Epoch: 30/100	 batch: 100/610	Train Loss: 1.0006
# Epoch: 30/100	 batch: 150/610	Train Loss: 1.0424
# Epoch: 30/100	 batch: 200/610	Train Loss: 0.9595
# Epoch: 30/100	 batch: 250/610	Train Loss: 0.9600
# Epoch: 30/100	 batch: 300/610	Train Loss: 0.9800
# Epoch: 30/100	 batch: 350/610	Train Loss: 0.9560
# Epoch: 30/100	 batch: 400/610	Train Loss: 1.0021
# Epoch: 30/100	 batch: 450/610	Train Loss: 0.9470
# Epoch: 30/100	 batch: 500/610	Train Loss: 0.9465
# Epoch: 30/100	 batch: 550/610	Train Loss: 0.9605
# Epoch: 30/100	 batch: 600/610	Train Loss: 0.9671
#
# Epoch 30/100	Train Loss: 0.9747	Test Loss: 0.9435	Train Acc: 0.7679	Test Acc: 0.7991	Best Acc: 0.7991
#
# Epoch: 31/100	 batch: 50/610	Train Loss: 1.0142
# Epoch: 31/100	 batch: 100/610	Train Loss: 0.9352
# Epoch: 31/100	 batch: 150/610	Train Loss: 1.0283
# Epoch: 31/100	 batch: 200/610	Train Loss: 0.9882
# Epoch: 31/100	 batch: 250/610	Train Loss: 0.9726
# Epoch: 31/100	 batch: 300/610	Train Loss: 1.0175
# Epoch: 31/100	 batch: 350/610	Train Loss: 0.9735
# Epoch: 31/100	 batch: 400/610	Train Loss: 1.0000
# Epoch: 31/100	 batch: 450/610	Train Loss: 0.9957
# Epoch: 31/100	 batch: 500/610	Train Loss: 0.9405
# Epoch: 31/100	 batch: 550/610	Train Loss: 0.9971
# Epoch: 31/100	 batch: 600/610	Train Loss: 0.9601
#
# Epoch 31/100	Train Loss: 0.9696	Test Loss: 1.0642	Train Acc: 0.7729	Test Acc: 0.6728	Best Acc: 0.7991
#
# Epoch: 32/100	 batch: 50/610	Train Loss: 0.9847
# Epoch: 32/100	 batch: 100/610	Train Loss: 0.9501
# Epoch: 32/100	 batch: 150/610	Train Loss: 0.9803
# Epoch: 32/100	 batch: 200/610	Train Loss: 0.9470
# Epoch: 32/100	 batch: 250/610	Train Loss: 0.9538
# Epoch: 32/100	 batch: 300/610	Train Loss: 0.9690
# Epoch: 32/100	 batch: 350/610	Train Loss: 0.9087
# Epoch: 32/100	 batch: 400/610	Train Loss: 0.9224
# Epoch: 32/100	 batch: 450/610	Train Loss: 1.0025
# Epoch: 32/100	 batch: 500/610	Train Loss: 0.9771
# Epoch: 32/100	 batch: 550/610	Train Loss: 0.9616
# Epoch: 32/100	 batch: 600/610	Train Loss: 0.9442
#
# Epoch 32/100	Train Loss: 0.9655	Test Loss: 0.9436	Train Acc: 0.7772	Test Acc: 0.7995	Best Acc: 0.7995
#
# Epoch: 33/100	 batch: 50/610	Train Loss: 0.9779
# Epoch: 33/100	 batch: 100/610	Train Loss: 0.9340
# Epoch: 33/100	 batch: 150/610	Train Loss: 0.9498
# Epoch: 33/100	 batch: 200/610	Train Loss: 0.9770
# Epoch: 33/100	 batch: 250/610	Train Loss: 0.9701
# Epoch: 33/100	 batch: 300/610	Train Loss: 0.9524
# Epoch: 33/100	 batch: 350/610	Train Loss: 0.9935
# Epoch: 33/100	 batch: 400/610	Train Loss: 0.9417
# Epoch: 33/100	 batch: 450/610	Train Loss: 0.9636
# Epoch: 33/100	 batch: 500/610	Train Loss: 0.9467
# Epoch: 33/100	 batch: 550/610	Train Loss: 0.9070
# Epoch: 33/100	 batch: 600/610	Train Loss: 0.9294
#
# Epoch 33/100	Train Loss: 0.9590	Test Loss: 0.9598	Train Acc: 0.7838	Test Acc: 0.7830	Best Acc: 0.7995
#
# Epoch: 34/100	 batch: 50/610	Train Loss: 0.9633
# Epoch: 34/100	 batch: 100/610	Train Loss: 1.0158
# Epoch: 34/100	 batch: 150/610	Train Loss: 0.9270
# Epoch: 34/100	 batch: 200/610	Train Loss: 0.9525
# Epoch: 34/100	 batch: 250/610	Train Loss: 0.9758
# Epoch: 34/100	 batch: 300/610	Train Loss: 0.9285
# Epoch: 34/100	 batch: 350/610	Train Loss: 0.9186
# Epoch: 34/100	 batch: 400/610	Train Loss: 0.9446
# Epoch: 34/100	 batch: 450/610	Train Loss: 0.9569
# Epoch: 34/100	 batch: 500/610	Train Loss: 0.9704
# Epoch: 34/100	 batch: 550/610	Train Loss: 0.9502
# Epoch: 34/100	 batch: 600/610	Train Loss: 0.9585
#
# Epoch 34/100	Train Loss: 0.9535	Test Loss: 0.9216	Train Acc: 0.7894	Test Acc: 0.8222	Best Acc: 0.8222
#
# Epoch: 35/100	 batch: 50/610	Train Loss: 0.8906
# Epoch: 35/100	 batch: 100/610	Train Loss: 0.9044
# Epoch: 35/100	 batch: 150/610	Train Loss: 0.9258
# Epoch: 35/100	 batch: 200/610	Train Loss: 0.9234
# Epoch: 35/100	 batch: 250/610	Train Loss: 0.9566
# Epoch: 35/100	 batch: 300/610	Train Loss: 0.9644
# Epoch: 35/100	 batch: 350/610	Train Loss: 0.9163
# Epoch: 35/100	 batch: 400/610	Train Loss: 0.9497
# Epoch: 35/100	 batch: 450/610	Train Loss: 1.0372
# Epoch: 35/100	 batch: 500/610	Train Loss: 0.9114
# Epoch: 35/100	 batch: 550/610	Train Loss: 0.9583
# Epoch: 35/100	 batch: 600/610	Train Loss: 0.9508
#
# Epoch 35/100	Train Loss: 0.9517	Test Loss: 0.9210	Train Acc: 0.7911	Test Acc: 0.8231	Best Acc: 0.8231
#
# Epoch: 36/100	 batch: 50/610	Train Loss: 0.9486
# Epoch: 36/100	 batch: 100/610	Train Loss: 0.9007
# Epoch: 36/100	 batch: 150/610	Train Loss: 0.9372
# Epoch: 36/100	 batch: 200/610	Train Loss: 0.8811
# Epoch: 36/100	 batch: 250/610	Train Loss: 0.9769
# Epoch: 36/100	 batch: 300/610	Train Loss: 0.9322
# Epoch: 36/100	 batch: 350/610	Train Loss: 0.9164
# Epoch: 36/100	 batch: 400/610	Train Loss: 0.9151
# Epoch: 36/100	 batch: 450/610	Train Loss: 0.9366
# Epoch: 36/100	 batch: 500/610	Train Loss: 0.9152
# Epoch: 36/100	 batch: 550/610	Train Loss: 1.0127
# Epoch: 36/100	 batch: 600/610	Train Loss: 0.9472
#
# Epoch 36/100	Train Loss: 0.9450	Test Loss: 0.9107	Train Acc: 0.7979	Test Acc: 0.8329	Best Acc: 0.8329
#
# Epoch: 37/100	 batch: 50/610	Train Loss: 0.9331
# Epoch: 37/100	 batch: 100/610	Train Loss: 0.9302
# Epoch: 37/100	 batch: 150/610	Train Loss: 0.9413
# Epoch: 37/100	 batch: 200/610	Train Loss: 0.9117
# Epoch: 37/100	 batch: 250/610	Train Loss: 0.9424
# Epoch: 37/100	 batch: 300/610	Train Loss: 0.9286
# Epoch: 37/100	 batch: 350/610	Train Loss: 0.9290
# Epoch: 37/100	 batch: 400/610	Train Loss: 0.9408
# Epoch: 37/100	 batch: 450/610	Train Loss: 0.9433
# Epoch: 37/100	 batch: 500/610	Train Loss: 0.9110
# Epoch: 37/100	 batch: 550/610	Train Loss: 0.9299
# Epoch: 37/100	 batch: 600/610	Train Loss: 0.9296
#
# Epoch 37/100	Train Loss: 0.9403	Test Loss: 0.9174	Train Acc: 0.8029	Test Acc: 0.8259	Best Acc: 0.8329
#
# Epoch: 38/100	 batch: 50/610	Train Loss: 0.9262
# Epoch: 38/100	 batch: 100/610	Train Loss: 0.8948
# Epoch: 38/100	 batch: 150/610	Train Loss: 0.9414
# Epoch: 38/100	 batch: 200/610	Train Loss: 0.9465
# Epoch: 38/100	 batch: 250/610	Train Loss: 0.9125
# Epoch: 38/100	 batch: 300/610	Train Loss: 0.9358
# Epoch: 38/100	 batch: 350/610	Train Loss: 0.9657
# Epoch: 38/100	 batch: 400/610	Train Loss: 0.9580
# Epoch: 38/100	 batch: 450/610	Train Loss: 0.9489
# Epoch: 38/100	 batch: 500/610	Train Loss: 0.9514
# Epoch: 38/100	 batch: 550/610	Train Loss: 1.0247
# Epoch: 38/100	 batch: 600/610	Train Loss: 0.9448
#
# Epoch 38/100	Train Loss: 0.9415	Test Loss: 0.9103	Train Acc: 0.8017	Test Acc: 0.8331	Best Acc: 0.8331
#
# Epoch: 39/100	 batch: 50/610	Train Loss: 0.9294
# Epoch: 39/100	 batch: 100/610	Train Loss: 0.9457
# Epoch: 39/100	 batch: 150/610	Train Loss: 0.9404
# Epoch: 39/100	 batch: 200/610	Train Loss: 0.9202
# Epoch: 39/100	 batch: 250/610	Train Loss: 0.9297
# Epoch: 39/100	 batch: 300/610	Train Loss: 0.9203
# Epoch: 39/100	 batch: 350/610	Train Loss: 0.9391
# Epoch: 39/100	 batch: 400/610	Train Loss: 0.9161
# Epoch: 39/100	 batch: 450/610	Train Loss: 0.9480
# Epoch: 39/100	 batch: 500/610	Train Loss: 0.9242
# Epoch: 39/100	 batch: 550/610	Train Loss: 0.9749
# Epoch: 39/100	 batch: 600/610	Train Loss: 0.9321
#
# Epoch 39/100	Train Loss: 0.9335	Test Loss: 0.9072	Train Acc: 0.8097	Test Acc: 0.8360	Best Acc: 0.8360
#
# Epoch: 40/100	 batch: 50/610	Train Loss: 0.9678
# Epoch: 40/100	 batch: 100/610	Train Loss: 0.9553
# Epoch: 40/100	 batch: 150/610	Train Loss: 0.9689
# Epoch: 40/100	 batch: 200/610	Train Loss: 0.9605
# Epoch: 40/100	 batch: 250/610	Train Loss: 0.9547
# Epoch: 40/100	 batch: 300/610	Train Loss: 0.8926
# Epoch: 40/100	 batch: 350/610	Train Loss: 0.9283
# Epoch: 40/100	 batch: 400/610	Train Loss: 0.9241
# Epoch: 40/100	 batch: 450/610	Train Loss: 0.9205
# Epoch: 40/100	 batch: 500/610	Train Loss: 0.9148
# Epoch: 40/100	 batch: 550/610	Train Loss: 0.9074
# Epoch: 40/100	 batch: 600/610	Train Loss: 0.8999
#
# Epoch 40/100	Train Loss: 0.9312	Test Loss: 0.9060	Train Acc: 0.8122	Test Acc: 0.8369	Best Acc: 0.8369
#
# Epoch: 41/100	 batch: 50/610	Train Loss: 0.9394
# Epoch: 41/100	 batch: 100/610	Train Loss: 0.9328
# Epoch: 41/100	 batch: 150/610	Train Loss: 0.9273
# Epoch: 41/100	 batch: 200/610	Train Loss: 0.9133
# Epoch: 41/100	 batch: 250/610	Train Loss: 0.9149
# Epoch: 41/100	 batch: 300/610	Train Loss: 0.9353
# Epoch: 41/100	 batch: 350/610	Train Loss: 0.9499
# Epoch: 41/100	 batch: 400/610	Train Loss: 0.9135
# Epoch: 41/100	 batch: 450/610	Train Loss: 0.9482
# Epoch: 41/100	 batch: 500/610	Train Loss: 0.9032
# Epoch: 41/100	 batch: 550/610	Train Loss: 0.9130
# Epoch: 41/100	 batch: 600/610	Train Loss: 0.9184
#
# Epoch 41/100	Train Loss: 0.9267	Test Loss: 0.9038	Train Acc: 0.8167	Test Acc: 0.8401	Best Acc: 0.8401
#
# Epoch: 42/100	 batch: 50/610	Train Loss: 0.8646
# Epoch: 42/100	 batch: 100/610	Train Loss: 0.9710
# Epoch: 42/100	 batch: 150/610	Train Loss: 0.9135
# Epoch: 42/100	 batch: 200/610	Train Loss: 0.9297
# Epoch: 42/100	 batch: 250/610	Train Loss: 0.8980
# Epoch: 42/100	 batch: 300/610	Train Loss: 0.9078
# Epoch: 42/100	 batch: 350/610	Train Loss: 0.9372
# Epoch: 42/100	 batch: 400/610	Train Loss: 0.9146
# Epoch: 42/100	 batch: 450/610	Train Loss: 0.9377
# Epoch: 42/100	 batch: 500/610	Train Loss: 0.9157
# Epoch: 42/100	 batch: 550/610	Train Loss: 0.9148
# Epoch: 42/100	 batch: 600/610	Train Loss: 0.9256
#
# Epoch 42/100	Train Loss: 0.9233	Test Loss: 0.8961	Train Acc: 0.8203	Test Acc: 0.8475	Best Acc: 0.8475
#
# Epoch: 43/100	 batch: 50/610	Train Loss: 0.8705
# Epoch: 43/100	 batch: 100/610	Train Loss: 0.9574
# Epoch: 43/100	 batch: 150/610	Train Loss: 0.8991
# Epoch: 43/100	 batch: 200/610	Train Loss: 0.9148
# Epoch: 43/100	 batch: 250/610	Train Loss: 0.9218
# Epoch: 43/100	 batch: 300/610	Train Loss: 0.9054
# Epoch: 43/100	 batch: 350/610	Train Loss: 0.8961
# Epoch: 43/100	 batch: 400/610	Train Loss: 0.9122
# Epoch: 43/100	 batch: 450/610	Train Loss: 0.9431
# Epoch: 43/100	 batch: 500/610	Train Loss: 0.9817
# Epoch: 43/100	 batch: 550/610	Train Loss: 0.9224
# Epoch: 43/100	 batch: 600/610	Train Loss: 0.9402
#
# Epoch 43/100	Train Loss: 0.9222	Test Loss: 0.8938	Train Acc: 0.8214	Test Acc: 0.8499	Best Acc: 0.8499
#
# Epoch: 44/100	 batch: 50/610	Train Loss: 0.9298
# Epoch: 44/100	 batch: 100/610	Train Loss: 0.8954
# Epoch: 44/100	 batch: 150/610	Train Loss: 0.9259
# Epoch: 44/100	 batch: 200/610	Train Loss: 0.8961
# Epoch: 44/100	 batch: 250/610	Train Loss: 0.9232
# Epoch: 44/100	 batch: 300/610	Train Loss: 0.9321
# Epoch: 44/100	 batch: 350/610	Train Loss: 0.9042
# Epoch: 44/100	 batch: 400/610	Train Loss: 0.9316
# Epoch: 44/100	 batch: 450/610	Train Loss: 0.8914
# Epoch: 44/100	 batch: 500/610	Train Loss: 0.9332
# Epoch: 44/100	 batch: 550/610	Train Loss: 0.9451
# Epoch: 44/100	 batch: 600/610	Train Loss: 0.9058
#
# Epoch 44/100	Train Loss: 0.9150	Test Loss: 0.8947	Train Acc: 0.8287	Test Acc: 0.8488	Best Acc: 0.8499
#
# Epoch: 45/100	 batch: 50/610	Train Loss: 0.9377
# Epoch: 45/100	 batch: 100/610	Train Loss: 0.8834
# Epoch: 45/100	 batch: 150/610	Train Loss: 0.9359
# Epoch: 45/100	 batch: 200/610	Train Loss: 0.9013
# Epoch: 45/100	 batch: 250/610	Train Loss: 0.9351
# Epoch: 45/100	 batch: 300/610	Train Loss: 0.9426
# Epoch: 45/100	 batch: 350/610	Train Loss: 0.9160
# Epoch: 45/100	 batch: 400/610	Train Loss: 0.8988
# Epoch: 45/100	 batch: 450/610	Train Loss: 0.9276
# Epoch: 45/100	 batch: 500/610	Train Loss: 0.8863
# Epoch: 45/100	 batch: 550/610	Train Loss: 0.9313
# Epoch: 45/100	 batch: 600/610	Train Loss: 0.9353
#
# Epoch 45/100	Train Loss: 0.9193	Test Loss: 0.8922	Train Acc: 0.8241	Test Acc: 0.8511	Best Acc: 0.8511
#
# Epoch: 46/100	 batch: 50/610	Train Loss: 0.9251
# Epoch: 46/100	 batch: 100/610	Train Loss: 0.9285
# Epoch: 46/100	 batch: 150/610	Train Loss: 0.9068
# Epoch: 46/100	 batch: 200/610	Train Loss: 0.9047
# Epoch: 46/100	 batch: 250/610	Train Loss: 0.8883
# Epoch: 46/100	 batch: 300/610	Train Loss: 0.8920
# Epoch: 46/100	 batch: 350/610	Train Loss: 0.8788
# Epoch: 46/100	 batch: 400/610	Train Loss: 0.9150
# Epoch: 46/100	 batch: 450/610	Train Loss: 0.9911
# Epoch: 46/100	 batch: 500/610	Train Loss: 0.8972
# Epoch: 46/100	 batch: 550/610	Train Loss: 0.8849
# Epoch: 46/100	 batch: 600/610	Train Loss: 0.9313
#
# Epoch 46/100	Train Loss: 0.9113	Test Loss: 0.8864	Train Acc: 0.8322	Test Acc: 0.8567	Best Acc: 0.8567
#
# Epoch: 47/100	 batch: 50/610	Train Loss: 0.9261
# Epoch: 47/100	 batch: 100/610	Train Loss: 0.9079
# Epoch: 47/100	 batch: 150/610	Train Loss: 0.9064
# Epoch: 47/100	 batch: 200/610	Train Loss: 0.9070
# Epoch: 47/100	 batch: 250/610	Train Loss: 0.8791
# Epoch: 47/100	 batch: 300/610	Train Loss: 0.9315
# Epoch: 47/100	 batch: 350/610	Train Loss: 0.9215
# Epoch: 47/100	 batch: 400/610	Train Loss: 0.9137
# Epoch: 47/100	 batch: 450/610	Train Loss: 0.9037
# Epoch: 47/100	 batch: 500/610	Train Loss: 0.8939
# Epoch: 47/100	 batch: 550/610	Train Loss: 0.9238
# Epoch: 47/100	 batch: 600/610	Train Loss: 0.9111
#
# Epoch 47/100	Train Loss: 0.9102	Test Loss: 0.8947	Train Acc: 0.8334	Test Acc: 0.8489	Best Acc: 0.8567
#
# Epoch: 48/100	 batch: 50/610	Train Loss: 0.8949
# Epoch: 48/100	 batch: 100/610	Train Loss: 0.9125
# Epoch: 48/100	 batch: 150/610	Train Loss: 0.9135
# Epoch: 48/100	 batch: 200/610	Train Loss: 0.9079
# Epoch: 48/100	 batch: 250/610	Train Loss: 0.9028
# Epoch: 48/100	 batch: 300/610	Train Loss: 0.8547
# Epoch: 48/100	 batch: 350/610	Train Loss: 0.9103
# Epoch: 48/100	 batch: 400/610	Train Loss: 0.8764
# Epoch: 48/100	 batch: 450/610	Train Loss: 0.8854
# Epoch: 48/100	 batch: 500/610	Train Loss: 0.8787
# Epoch: 48/100	 batch: 550/610	Train Loss: 0.8636
# Epoch: 48/100	 batch: 600/610	Train Loss: 0.8817
#
# Epoch 48/100	Train Loss: 0.9049	Test Loss: 0.8907	Train Acc: 0.8389	Test Acc: 0.8531	Best Acc: 0.8567
#
# Epoch: 49/100	 batch: 50/610	Train Loss: 0.9205
# Epoch: 49/100	 batch: 100/610	Train Loss: 0.8835
# Epoch: 49/100	 batch: 150/610	Train Loss: 0.8937
# Epoch: 49/100	 batch: 200/610	Train Loss: 0.9001
# Epoch: 49/100	 batch: 250/610	Train Loss: 0.9222
# Epoch: 49/100	 batch: 300/610	Train Loss: 0.9440
# Epoch: 49/100	 batch: 350/610	Train Loss: 0.9591
# Epoch: 49/100	 batch: 400/610	Train Loss: 0.8993
# Epoch: 49/100	 batch: 450/610	Train Loss: 0.8721
# Epoch: 49/100	 batch: 500/610	Train Loss: 0.9223
# Epoch: 49/100	 batch: 550/610	Train Loss: 0.8900
# Epoch: 49/100	 batch: 600/610	Train Loss: 0.8842
#
# Epoch 49/100	Train Loss: 0.9066	Test Loss: 0.8819	Train Acc: 0.8369	Test Acc: 0.8613	Best Acc: 0.8613
#
# Epoch: 50/100	 batch: 50/610	Train Loss: 0.8936
# Epoch: 50/100	 batch: 100/610	Train Loss: 0.8650
# Epoch: 50/100	 batch: 150/610	Train Loss: 0.8629
# Epoch: 50/100	 batch: 200/610	Train Loss: 0.8835
# Epoch: 50/100	 batch: 250/610	Train Loss: 0.8900
# Epoch: 50/100	 batch: 300/610	Train Loss: 0.9232
# Epoch: 50/100	 batch: 350/610	Train Loss: 0.8885
# Epoch: 50/100	 batch: 400/610	Train Loss: 0.8863
# Epoch: 50/100	 batch: 450/610	Train Loss: 0.9012
# Epoch: 50/100	 batch: 500/610	Train Loss: 0.8998
# Epoch: 50/100	 batch: 550/610	Train Loss: 0.9424
# Epoch: 50/100	 batch: 600/610	Train Loss: 0.9349
#
# Epoch 50/100	Train Loss: 0.9006	Test Loss: 0.8826	Train Acc: 0.8431	Test Acc: 0.8606	Best Acc: 0.8613
#
# Epoch: 51/100	 batch: 50/610	Train Loss: 0.8967
# Epoch: 51/100	 batch: 100/610	Train Loss: 0.9118
# Epoch: 51/100	 batch: 150/610	Train Loss: 0.9219
# Epoch: 51/100	 batch: 200/610	Train Loss: 0.9588
# Epoch: 51/100	 batch: 250/610	Train Loss: 0.9041
# Epoch: 51/100	 batch: 300/610	Train Loss: 0.9424
# Epoch: 51/100	 batch: 350/610	Train Loss: 0.8961
# Epoch: 51/100	 batch: 400/610	Train Loss: 0.8938
# Epoch: 51/100	 batch: 450/610	Train Loss: 0.8717
# Epoch: 51/100	 batch: 500/610	Train Loss: 0.9033
# Epoch: 51/100	 batch: 550/610	Train Loss: 0.9027
# Epoch: 51/100	 batch: 600/610	Train Loss: 0.8843
#
# Epoch 51/100	Train Loss: 0.9014	Test Loss: 0.8838	Train Acc: 0.8422	Test Acc: 0.8596	Best Acc: 0.8613
#
# Epoch: 52/100	 batch: 50/610	Train Loss: 0.8948
# Epoch: 52/100	 batch: 100/610	Train Loss: 0.8699
# Epoch: 52/100	 batch: 150/610	Train Loss: 0.9087
# Epoch: 52/100	 batch: 200/610	Train Loss: 0.8978
# Epoch: 52/100	 batch: 250/610	Train Loss: 0.9099
# Epoch: 52/100	 batch: 300/610	Train Loss: 0.9178
# Epoch: 52/100	 batch: 350/610	Train Loss: 0.9490
# Epoch: 52/100	 batch: 400/610	Train Loss: 0.9727
# Epoch: 52/100	 batch: 450/610	Train Loss: 0.8959
# Epoch: 52/100	 batch: 500/610	Train Loss: 0.8925
# Epoch: 52/100	 batch: 550/610	Train Loss: 0.9437
# Epoch: 52/100	 batch: 600/610	Train Loss: 0.9124
#
# Epoch 52/100	Train Loss: 0.9015	Test Loss: 0.8935	Train Acc: 0.8421	Test Acc: 0.8506	Best Acc: 0.8613
#
# Epoch: 53/100	 batch: 50/610	Train Loss: 0.9057
# Epoch: 53/100	 batch: 100/610	Train Loss: 0.8664
# Epoch: 53/100	 batch: 150/610	Train Loss: 0.8896
# Epoch: 53/100	 batch: 200/610	Train Loss: 0.8958
# Epoch: 53/100	 batch: 250/610	Train Loss: 0.9433
# Epoch: 53/100	 batch: 300/610	Train Loss: 0.8832
# Epoch: 53/100	 batch: 350/610	Train Loss: 0.8757
# Epoch: 53/100	 batch: 400/610	Train Loss: 0.8876
# Epoch: 53/100	 batch: 450/610	Train Loss: 0.8884
# Epoch: 53/100	 batch: 500/610	Train Loss: 0.8623
# Epoch: 53/100	 batch: 550/610	Train Loss: 0.9032
# Epoch: 53/100	 batch: 600/610	Train Loss: 0.9322
#
# Epoch 53/100	Train Loss: 0.8963	Test Loss: 0.8779	Train Acc: 0.8473	Test Acc: 0.8654	Best Acc: 0.8654
#
# Epoch: 54/100	 batch: 50/610	Train Loss: 0.9024
# Epoch: 54/100	 batch: 100/610	Train Loss: 0.9381
# Epoch: 54/100	 batch: 150/610	Train Loss: 0.8904
# Epoch: 54/100	 batch: 200/610	Train Loss: 0.9001
# Epoch: 54/100	 batch: 250/610	Train Loss: 0.9169
# Epoch: 54/100	 batch: 300/610	Train Loss: 0.8996
# Epoch: 54/100	 batch: 350/610	Train Loss: 0.8701
# Epoch: 54/100	 batch: 400/610	Train Loss: 0.9074
# Epoch: 54/100	 batch: 450/610	Train Loss: 0.8659
# Epoch: 54/100	 batch: 500/610	Train Loss: 0.8835
# Epoch: 54/100	 batch: 550/610	Train Loss: 0.9056
# Epoch: 54/100	 batch: 600/610	Train Loss: 0.9286
#
# Epoch 54/100	Train Loss: 0.8938	Test Loss: 0.8822	Train Acc: 0.8498	Test Acc: 0.8612	Best Acc: 0.8654
#
# Epoch: 55/100	 batch: 50/610	Train Loss: 0.8894
# Epoch: 55/100	 batch: 100/610	Train Loss: 0.8841
# Epoch: 55/100	 batch: 150/610	Train Loss: 0.8985
# Epoch: 55/100	 batch: 200/610	Train Loss: 0.8459
# Epoch: 55/100	 batch: 250/610	Train Loss: 0.8978
# Epoch: 55/100	 batch: 300/610	Train Loss: 0.9248
# Epoch: 55/100	 batch: 350/610	Train Loss: 0.8925
# Epoch: 55/100	 batch: 400/610	Train Loss: 0.9144
# Epoch: 55/100	 batch: 450/610	Train Loss: 0.8581
# Epoch: 55/100	 batch: 500/610	Train Loss: 0.8771
# Epoch: 55/100	 batch: 550/610	Train Loss: 0.9211
# Epoch: 55/100	 batch: 600/610	Train Loss: 0.8812
#
# Epoch 55/100	Train Loss: 0.8927	Test Loss: 0.8822	Train Acc: 0.8511	Test Acc: 0.8614	Best Acc: 0.8654
#
# Epoch: 56/100	 batch: 50/610	Train Loss: 0.9121
# Epoch: 56/100	 batch: 100/610	Train Loss: 0.9213
# Epoch: 56/100	 batch: 150/610	Train Loss: 0.8411
# Epoch: 56/100	 batch: 200/610	Train Loss: 0.8639
# Epoch: 56/100	 batch: 250/610	Train Loss: 0.9044
# Epoch: 56/100	 batch: 300/610	Train Loss: 0.9053
# Epoch: 56/100	 batch: 350/610	Train Loss: 0.8346
# Epoch: 56/100	 batch: 400/610	Train Loss: 0.8846
# Epoch: 56/100	 batch: 450/610	Train Loss: 0.8456
# Epoch: 56/100	 batch: 500/610	Train Loss: 0.8781
# Epoch: 56/100	 batch: 550/610	Train Loss: 0.8718
# Epoch: 56/100	 batch: 600/610	Train Loss: 0.8773
#
# Epoch 56/100	Train Loss: 0.8906	Test Loss: 0.8789	Train Acc: 0.8530	Test Acc: 0.8645	Best Acc: 0.8654
#
# Epoch: 57/100	 batch: 50/610	Train Loss: 0.8864
# Epoch: 57/100	 batch: 100/610	Train Loss: 0.8957
# Epoch: 57/100	 batch: 150/610	Train Loss: 0.9013
# Epoch: 57/100	 batch: 200/610	Train Loss: 0.8901
# Epoch: 57/100	 batch: 250/610	Train Loss: 0.8675
# Epoch: 57/100	 batch: 300/610	Train Loss: 0.8558
# Epoch: 57/100	 batch: 350/610	Train Loss: 0.8540
# Epoch: 57/100	 batch: 400/610	Train Loss: 0.8891
# Epoch: 57/100	 batch: 450/610	Train Loss: 0.9351
# Epoch: 57/100	 batch: 500/610	Train Loss: 0.8978
# Epoch: 57/100	 batch: 550/610	Train Loss: 0.9142
# Epoch: 57/100	 batch: 600/610	Train Loss: 0.8849
#
# Epoch 57/100	Train Loss: 0.8912	Test Loss: 0.8768	Train Acc: 0.8525	Test Acc: 0.8666	Best Acc: 0.8666
#
# Epoch: 58/100	 batch: 50/610	Train Loss: 0.9311
# Epoch: 58/100	 batch: 100/610	Train Loss: 0.8887
# Epoch: 58/100	 batch: 150/610	Train Loss: 0.8519
# Epoch: 58/100	 batch: 200/610	Train Loss: 0.9416
# Epoch: 58/100	 batch: 250/610	Train Loss: 0.8554
# Epoch: 58/100	 batch: 300/610	Train Loss: 0.8647
# Epoch: 58/100	 batch: 350/610	Train Loss: 0.9381
# Epoch: 58/100	 batch: 400/610	Train Loss: 0.9357
# Epoch: 58/100	 batch: 450/610	Train Loss: 0.8959
# Epoch: 58/100	 batch: 500/610	Train Loss: 0.8932
# Epoch: 58/100	 batch: 550/610	Train Loss: 0.8800
# Epoch: 58/100	 batch: 600/610	Train Loss: 0.8713
#
# Epoch 58/100	Train Loss: 0.8906	Test Loss: 0.8729	Train Acc: 0.8532	Test Acc: 0.8702	Best Acc: 0.8702
#
# Epoch: 59/100	 batch: 50/610	Train Loss: 0.8730
# Epoch: 59/100	 batch: 100/610	Train Loss: 0.8398
# Epoch: 59/100	 batch: 150/610	Train Loss: 0.8605
# Epoch: 59/100	 batch: 200/610	Train Loss: 0.8795
# Epoch: 59/100	 batch: 250/610	Train Loss: 0.8661
# Epoch: 59/100	 batch: 300/610	Train Loss: 0.8932
# Epoch: 59/100	 batch: 350/610	Train Loss: 0.8966
# Epoch: 59/100	 batch: 400/610	Train Loss: 0.9128
# Epoch: 59/100	 batch: 450/610	Train Loss: 0.8860
# Epoch: 59/100	 batch: 500/610	Train Loss: 0.8722
# Epoch: 59/100	 batch: 550/610	Train Loss: 0.9196
# Epoch: 59/100	 batch: 600/610	Train Loss: 0.9411
#
# Epoch 59/100	Train Loss: 0.8857	Test Loss: 0.8799	Train Acc: 0.8581	Test Acc: 0.8634	Best Acc: 0.8702
#
# Epoch: 60/100	 batch: 50/610	Train Loss: 0.9035
# Epoch: 60/100	 batch: 100/610	Train Loss: 0.9050
# Epoch: 60/100	 batch: 150/610	Train Loss: 0.8814
# Epoch: 60/100	 batch: 200/610	Train Loss: 0.9181
# Epoch: 60/100	 batch: 250/610	Train Loss: 0.8592
# Epoch: 60/100	 batch: 300/610	Train Loss: 0.8654
# Epoch: 60/100	 batch: 350/610	Train Loss: 0.9161
# Epoch: 60/100	 batch: 400/610	Train Loss: 0.9283
# Epoch: 60/100	 batch: 450/610	Train Loss: 0.9166
# Epoch: 60/100	 batch: 500/610	Train Loss: 0.8581
# Epoch: 60/100	 batch: 550/610	Train Loss: 0.8990
# Epoch: 60/100	 batch: 600/610	Train Loss: 0.8760
#
# Epoch 60/100	Train Loss: 0.8885	Test Loss: 0.8707	Train Acc: 0.8552	Test Acc: 0.8726	Best Acc: 0.8726
#
# Epoch: 61/100	 batch: 50/610	Train Loss: 0.8739
# Epoch: 61/100	 batch: 100/610	Train Loss: 0.8832
# Epoch: 61/100	 batch: 150/610	Train Loss: 0.8980
# Epoch: 61/100	 batch: 200/610	Train Loss: 0.8705
# Epoch: 61/100	 batch: 250/610	Train Loss: 0.9022
# Epoch: 61/100	 batch: 300/610	Train Loss: 0.8508
# Epoch: 61/100	 batch: 350/610	Train Loss: 0.8871
# Epoch: 61/100	 batch: 400/610	Train Loss: 0.8532
# Epoch: 61/100	 batch: 450/610	Train Loss: 0.8968
# Epoch: 61/100	 batch: 500/610	Train Loss: 0.8709
# Epoch: 61/100	 batch: 550/610	Train Loss: 0.9033
# Epoch: 61/100	 batch: 600/610	Train Loss: 0.8728
#
# Epoch 61/100	Train Loss: 0.8848	Test Loss: 0.8683	Train Acc: 0.8589	Test Acc: 0.8747	Best Acc: 0.8747
#
# Epoch: 62/100	 batch: 50/610	Train Loss: 0.8373
# Epoch: 62/100	 batch: 100/610	Train Loss: 0.8486
# Epoch: 62/100	 batch: 150/610	Train Loss: 0.8853
# Epoch: 62/100	 batch: 200/610	Train Loss: 0.8984
# Epoch: 62/100	 batch: 250/610	Train Loss: 0.8783
# Epoch: 62/100	 batch: 300/610	Train Loss: 0.8919
# Epoch: 62/100	 batch: 350/610	Train Loss: 0.9188
# Epoch: 62/100	 batch: 400/610	Train Loss: 0.8206
# Epoch: 62/100	 batch: 450/610	Train Loss: 0.8855
# Epoch: 62/100	 batch: 500/610	Train Loss: 0.8995
# Epoch: 62/100	 batch: 550/610	Train Loss: 0.8758
# Epoch: 62/100	 batch: 600/610	Train Loss: 0.8553
#
# Epoch 62/100	Train Loss: 0.8835	Test Loss: 0.8676	Train Acc: 0.8600	Test Acc: 0.8756	Best Acc: 0.8756
#
# Epoch: 63/100	 batch: 50/610	Train Loss: 0.8753
# Epoch: 63/100	 batch: 100/610	Train Loss: 0.8869
# Epoch: 63/100	 batch: 150/610	Train Loss: 0.8796
# Epoch: 63/100	 batch: 200/610	Train Loss: 0.8976
# Epoch: 63/100	 batch: 250/610	Train Loss: 0.8733
# Epoch: 63/100	 batch: 300/610	Train Loss: 0.8827
# Epoch: 63/100	 batch: 350/610	Train Loss: 0.8907
# Epoch: 63/100	 batch: 400/610	Train Loss: 0.9133
# Epoch: 63/100	 batch: 450/610	Train Loss: 0.9169
# Epoch: 63/100	 batch: 500/610	Train Loss: 0.8467
# Epoch: 63/100	 batch: 550/610	Train Loss: 0.9247
# Epoch: 63/100	 batch: 600/610	Train Loss: 0.8447
#
# Epoch 63/100	Train Loss: 0.8834	Test Loss: 0.8732	Train Acc: 0.8605	Test Acc: 0.8705	Best Acc: 0.8756
#
# Epoch: 64/100	 batch: 50/610	Train Loss: 0.8330
# Epoch: 64/100	 batch: 100/610	Train Loss: 0.8789
# Epoch: 64/100	 batch: 150/610	Train Loss: 0.8791
# Epoch: 64/100	 batch: 200/610	Train Loss: 0.8957
# Epoch: 64/100	 batch: 250/610	Train Loss: 0.9224
# Epoch: 64/100	 batch: 300/610	Train Loss: 0.8557
# Epoch: 64/100	 batch: 350/610	Train Loss: 0.8951
# Epoch: 64/100	 batch: 400/610	Train Loss: 0.8514
# Epoch: 64/100	 batch: 450/610	Train Loss: 0.8775
# Epoch: 64/100	 batch: 500/610	Train Loss: 0.8685
# Epoch: 64/100	 batch: 550/610	Train Loss: 0.8366
# Epoch: 64/100	 batch: 600/610	Train Loss: 0.8815
#
# Epoch 64/100	Train Loss: 0.8801	Test Loss: 0.8673	Train Acc: 0.8637	Test Acc: 0.8758	Best Acc: 0.8758
#
# Epoch: 65/100	 batch: 50/610	Train Loss: 0.8779
# Epoch: 65/100	 batch: 100/610	Train Loss: 0.8773
# Epoch: 65/100	 batch: 150/610	Train Loss: 0.8823
# Epoch: 65/100	 batch: 200/610	Train Loss: 0.9014
# Epoch: 65/100	 batch: 250/610	Train Loss: 0.9126
# Epoch: 65/100	 batch: 300/610	Train Loss: 0.9050
# Epoch: 65/100	 batch: 350/610	Train Loss: 0.8852
# Epoch: 65/100	 batch: 400/610	Train Loss: 0.8320
# Epoch: 65/100	 batch: 450/610	Train Loss: 0.8298
# Epoch: 65/100	 batch: 500/610	Train Loss: 0.8770
# Epoch: 65/100	 batch: 550/610	Train Loss: 0.9014
# Epoch: 65/100	 batch: 600/610	Train Loss: 0.9052
#
# Epoch 65/100	Train Loss: 0.8779	Test Loss: 0.8644	Train Acc: 0.8659	Test Acc: 0.8786	Best Acc: 0.8786
#
# Epoch: 66/100	 batch: 50/610	Train Loss: 0.8814
# Epoch: 66/100	 batch: 100/610	Train Loss: 0.8744
# Epoch: 66/100	 batch: 150/610	Train Loss: 0.8809
# Epoch: 66/100	 batch: 200/610	Train Loss: 0.8944
# Epoch: 66/100	 batch: 250/610	Train Loss: 0.8474
# Epoch: 66/100	 batch: 300/610	Train Loss: 0.8423
# Epoch: 66/100	 batch: 350/610	Train Loss: 0.8843
# Epoch: 66/100	 batch: 400/610	Train Loss: 0.8892
# Epoch: 66/100	 batch: 450/610	Train Loss: 0.9260
# Epoch: 66/100	 batch: 500/610	Train Loss: 0.8954
# Epoch: 66/100	 batch: 550/610	Train Loss: 0.8920
# Epoch: 66/100	 batch: 600/610	Train Loss: 0.8817
#
# Epoch 66/100	Train Loss: 0.8776	Test Loss: 0.8689	Train Acc: 0.8663	Test Acc: 0.8745	Best Acc: 0.8786
#
# Epoch: 67/100	 batch: 50/610	Train Loss: 0.9062
# Epoch: 67/100	 batch: 100/610	Train Loss: 0.8578
# Epoch: 67/100	 batch: 150/610	Train Loss: 0.8431
# Epoch: 67/100	 batch: 200/610	Train Loss: 0.8430
# Epoch: 67/100	 batch: 250/610	Train Loss: 0.9023
# Epoch: 67/100	 batch: 300/610	Train Loss: 0.9004
# Epoch: 67/100	 batch: 350/610	Train Loss: 0.8986
# Epoch: 67/100	 batch: 400/610	Train Loss: 0.8725
# Epoch: 67/100	 batch: 450/610	Train Loss: 0.8629
# Epoch: 67/100	 batch: 500/610	Train Loss: 0.9103
# Epoch: 67/100	 batch: 550/610	Train Loss: 0.8463
# Epoch: 67/100	 batch: 600/610	Train Loss: 0.8349
#
# Epoch 67/100	Train Loss: 0.8785	Test Loss: 0.8640	Train Acc: 0.8654	Test Acc: 0.8789	Best Acc: 0.8789
#
# Epoch: 68/100	 batch: 50/610	Train Loss: 0.9110
# Epoch: 68/100	 batch: 100/610	Train Loss: 0.8568
# Epoch: 68/100	 batch: 150/610	Train Loss: 0.8615
# Epoch: 68/100	 batch: 200/610	Train Loss: 0.8459
# Epoch: 68/100	 batch: 250/610	Train Loss: 0.8835
# Epoch: 68/100	 batch: 300/610	Train Loss: 0.8520
# Epoch: 68/100	 batch: 350/610	Train Loss: 0.9125
# Epoch: 68/100	 batch: 400/610	Train Loss: 0.8997
# Epoch: 68/100	 batch: 450/610	Train Loss: 0.8638
# Epoch: 68/100	 batch: 500/610	Train Loss: 0.9014
# Epoch: 68/100	 batch: 550/610	Train Loss: 0.8681
# Epoch: 68/100	 batch: 600/610	Train Loss: 0.8600
#
# Epoch 68/100	Train Loss: 0.8743	Test Loss: 0.8600	Train Acc: 0.8694	Test Acc: 0.8830	Best Acc: 0.8830
#
# Epoch: 69/100	 batch: 50/610	Train Loss: 0.8387
# Epoch: 69/100	 batch: 100/610	Train Loss: 0.8935
# Epoch: 69/100	 batch: 150/610	Train Loss: 0.8644
# Epoch: 69/100	 batch: 200/610	Train Loss: 0.8631
# Epoch: 69/100	 batch: 250/610	Train Loss: 0.8875
# Epoch: 69/100	 batch: 300/610	Train Loss: 0.9041
# ...
# Epoch: 78/100	 batch: 250/610	Train Loss: 0.8383
# Epoch: 78/100	 batch: 300/610	Train Loss: 0.8807
# Epoch: 78/100	 batch: 350/610	Train Loss: 0.8799
# Epoch: 78/100	 batch: 400/610	Train Loss: 0.8739
# Epoch: 78/100	 batch: 450/610	Train Loss: 0.8635
# Epoch: 78/100	 batch: 500/610	Train Loss: 0.9224
# Epoch: 78/100	 batch: 550/610	Train Loss: 0.8719
# Epoch: 78/100	 batch: 600/610	Train Loss: 0.8468
#
# Epoch 78/100	Train Loss: 0.8664	Test Loss: 0.8819	Train Acc: 0.8774	Test Acc: 0.8606	Best Acc: 0.8877
#
# Epoch: 79/100	 batch: 50/610	Train Loss: 0.8781
# Epoch: 79/100	 batch: 100/610	Train Loss: 0.8423
# Epoch: 79/100	 batch: 150/610	Train Loss: 0.9049
# Epoch: 79/100	 batch: 200/610	Train Loss: 0.8423
# Epoch: 79/100	 batch: 250/610	Train Loss: 0.8864
# Epoch: 79/100	 batch: 300/610	Train Loss: 0.8540
# Epoch: 79/100	 batch: 350/610	Train Loss: 0.8663
# Epoch: 79/100	 batch: 400/610	Train Loss: 0.8517
# Epoch: 79/100	 batch: 450/610	Train Loss: 0.8604
# Epoch: 79/100	 batch: 500/610	Train Loss: 0.8586
# Epoch: 79/100	 batch: 550/610	Train Loss: 0.8601
# Epoch: 79/100	 batch: 600/610	Train Loss: 0.8549
#
# Epoch 79/100	Train Loss: 0.8663	Test Loss: 0.8542	Train Acc: 0.8776	Test Acc: 0.8888	Best Acc: 0.8888
#
# Epoch: 80/100	 batch: 50/610	Train Loss: 0.8562
# Epoch: 80/100	 batch: 100/610	Train Loss: 0.8810
# Epoch: 80/100	 batch: 150/610	Train Loss: 0.8810
# Epoch: 80/100	 batch: 200/610	Train Loss: 0.8712
# Epoch: 80/100	 batch: 250/610	Train Loss: 0.8746
# Epoch: 80/100	 batch: 300/610	Train Loss: 0.8930
# Epoch: 80/100	 batch: 350/610	Train Loss: 0.9062
# Epoch: 80/100	 batch: 400/610	Train Loss: 0.8506
# Epoch: 80/100	 batch: 450/610	Train Loss: 0.9548
# Epoch: 80/100	 batch: 500/610	Train Loss: 0.8747
# Epoch: 80/100	 batch: 550/610	Train Loss: 0.8654
# Epoch: 80/100	 batch: 600/610	Train Loss: 0.8840
#
# Epoch 80/100	Train Loss: 0.8660	Test Loss: 0.8620	Train Acc: 0.8778	Test Acc: 0.8818	Best Acc: 0.8888
#
# Epoch: 81/100	 batch: 50/610	Train Loss: 0.8576
# Epoch: 81/100	 batch: 100/610	Train Loss: 0.8437
# Epoch: 81/100	 batch: 150/610	Train Loss: 0.8693
# Epoch: 81/100	 batch: 200/610	Train Loss: 0.8810
# Epoch: 81/100	 batch: 250/610	Train Loss: 0.8702
# Epoch: 81/100	 batch: 300/610	Train Loss: 0.8628
# Epoch: 81/100	 batch: 350/610	Train Loss: 0.8818
# Epoch: 81/100	 batch: 400/610	Train Loss: 0.8544
# Epoch: 81/100	 batch: 450/610	Train Loss: 0.9146
# Epoch: 81/100	 batch: 500/610	Train Loss: 0.8814
# Epoch: 81/100	 batch: 550/610	Train Loss: 0.8778
# Epoch: 81/100	 batch: 600/610	Train Loss: 0.9131
#
# Epoch 81/100	Train Loss: 0.8622	Test Loss: 0.8553	Train Acc: 0.8814	Test Acc: 0.8880	Best Acc: 0.8888
#
# Epoch: 82/100	 batch: 50/610	Train Loss: 0.8760
# Epoch: 82/100	 batch: 100/610	Train Loss: 0.8596
# Epoch: 82/100	 batch: 150/610	Train Loss: 0.8490
# Epoch: 82/100	 batch: 200/610	Train Loss: 0.8767
# Epoch: 82/100	 batch: 250/610	Train Loss: 0.8652
# Epoch: 82/100	 batch: 300/610	Train Loss: 0.8657
# Epoch: 82/100	 batch: 350/610	Train Loss: 0.8350
# Epoch: 82/100	 batch: 400/610	Train Loss: 0.8338
# Epoch: 82/100	 batch: 450/610	Train Loss: 0.8409
# Epoch: 82/100	 batch: 500/610	Train Loss: 0.8528
# Epoch: 82/100	 batch: 550/610	Train Loss: 0.8318
# Epoch: 82/100	 batch: 600/610	Train Loss: 0.8755
#
# Epoch 82/100	Train Loss: 0.8612	Test Loss: 0.8598	Train Acc: 0.8826	Test Acc: 0.8836	Best Acc: 0.8888
#
# Epoch: 83/100	 batch: 50/610	Train Loss: 0.8557
# Epoch: 83/100	 batch: 100/610	Train Loss: 0.8399
# Epoch: 83/100	 batch: 150/610	Train Loss: 0.8620
# Epoch: 83/100	 batch: 200/610	Train Loss: 0.9118
# Epoch: 83/100	 batch: 250/610	Train Loss: 0.8723
# Epoch: 83/100	 batch: 300/610	Train Loss: 0.8515
# Epoch: 83/100	 batch: 350/610	Train Loss: 0.8509
# Epoch: 83/100	 batch: 400/610	Train Loss: 0.8864
# Epoch: 83/100	 batch: 450/610	Train Loss: 0.8585
# Epoch: 83/100	 batch: 500/610	Train Loss: 0.8653
# Epoch: 83/100	 batch: 550/610	Train Loss: 0.8726
# Epoch: 83/100	 batch: 600/610	Train Loss: 0.8534
#
# Epoch 83/100	Train Loss: 0.8625	Test Loss: 0.8495	Train Acc: 0.8813	Test Acc: 0.8934	Best Acc: 0.8934
#
# Epoch: 84/100	 batch: 50/610	Train Loss: 0.8665
# Epoch: 84/100	 batch: 100/610	Train Loss: 0.8492
# Epoch: 84/100	 batch: 150/610	Train Loss: 0.8491
# Epoch: 84/100	 batch: 200/610	Train Loss: 0.8389
# Epoch: 84/100	 batch: 250/610	Train Loss: 0.8581
# Epoch: 84/100	 batch: 300/610	Train Loss: 0.8513
# Epoch: 84/100	 batch: 350/610	Train Loss: 0.8544
# Epoch: 84/100	 batch: 400/610	Train Loss: 0.8598
# Epoch: 84/100	 batch: 450/610	Train Loss: 0.8544
# Epoch: 84/100	 batch: 500/610	Train Loss: 0.8520
# Epoch: 84/100	 batch: 550/610	Train Loss: 0.8769
# Epoch: 84/100	 batch: 600/610	Train Loss: 0.8727
#
# Epoch 84/100	Train Loss: 0.8594	Test Loss: 0.8523	Train Acc: 0.8844	Test Acc: 0.8911	Best Acc: 0.8934
#
# Epoch: 85/100	 batch: 50/610	Train Loss: 0.8648
# Epoch: 85/100	 batch: 100/610	Train Loss: 0.8836
# Epoch: 85/100	 batch: 150/610	Train Loss: 0.8628
# Epoch: 85/100	 batch: 200/610	Train Loss: 0.8511
# Epoch: 85/100	 batch: 250/610	Train Loss: 0.8698
# Epoch: 85/100	 batch: 300/610	Train Loss: 0.8681
# Epoch: 85/100	 batch: 350/610	Train Loss: 0.8838
# Epoch: 85/100	 batch: 400/610	Train Loss: 0.9190
# Epoch: 85/100	 batch: 450/610	Train Loss: 0.8466
# Epoch: 85/100	 batch: 500/610	Train Loss: 0.8449
# Epoch: 85/100	 batch: 550/610	Train Loss: 0.8760
# Epoch: 85/100	 batch: 600/610	Train Loss: 0.8721
#
# Epoch 85/100	Train Loss: 0.8595	Test Loss: 0.8629	Train Acc: 0.8843	Test Acc: 0.8805	Best Acc: 0.8934
#
# Epoch: 86/100	 batch: 50/610	Train Loss: 0.8759
# Epoch: 86/100	 batch: 100/610	Train Loss: 0.8474
# Epoch: 86/100	 batch: 150/610	Train Loss: 0.8593
# Epoch: 86/100	 batch: 200/610	Train Loss: 0.8662
# Epoch: 86/100	 batch: 250/610	Train Loss: 0.8489
# Epoch: 86/100	 batch: 300/610	Train Loss: 0.8632
# Epoch: 86/100	 batch: 350/610	Train Loss: 0.8478
# Epoch: 86/100	 batch: 400/610	Train Loss: 0.8512
# Epoch: 86/100	 batch: 450/610	Train Loss: 0.8434
# Epoch: 86/100	 batch: 500/610	Train Loss: 0.8491
# Epoch: 86/100	 batch: 550/610	Train Loss: 0.8941
# Epoch: 86/100	 batch: 600/610	Train Loss: 0.8721
#
# Epoch 86/100	Train Loss: 0.8586	Test Loss: 0.8534	Train Acc: 0.8851	Test Acc: 0.8901	Best Acc: 0.8934
#
# Epoch: 87/100	 batch: 50/610	Train Loss: 0.8518
# Epoch: 87/100	 batch: 100/610	Train Loss: 0.8332
# Epoch: 87/100	 batch: 150/610	Train Loss: 0.8412
# Epoch: 87/100	 batch: 200/610	Train Loss: 0.8409
# Epoch: 87/100	 batch: 250/610	Train Loss: 0.8431
# Epoch: 87/100	 batch: 300/610	Train Loss: 0.8669
# Epoch: 87/100	 batch: 350/610	Train Loss: 0.8700
# Epoch: 87/100	 batch: 400/610	Train Loss: 0.8517
# Epoch: 87/100	 batch: 450/610	Train Loss: 0.8821
# Epoch: 87/100	 batch: 500/610	Train Loss: 0.8539
# Epoch: 87/100	 batch: 550/610	Train Loss: 0.8437
# Epoch: 87/100	 batch: 600/610	Train Loss: 0.8539
#
# Epoch 87/100	Train Loss: 0.8604	Test Loss: 0.8516	Train Acc: 0.8835	Test Acc: 0.8915	Best Acc: 0.8934
#
# Epoch: 88/100	 batch: 50/610	Train Loss: 0.8338
# Epoch: 88/100	 batch: 100/610	Train Loss: 0.8183
# Epoch: 88/100	 batch: 150/610	Train Loss: 0.8584
# Epoch: 88/100	 batch: 200/610	Train Loss: 0.8377
# Epoch: 88/100	 batch: 250/610	Train Loss: 0.9344
# Epoch: 88/100	 batch: 300/610	Train Loss: 0.8665
# Epoch: 88/100	 batch: 350/610	Train Loss: 0.8226
# Epoch: 88/100	 batch: 400/610	Train Loss: 0.8678
# Epoch: 88/100	 batch: 450/610	Train Loss: 0.8728
# Epoch: 88/100	 batch: 500/610	Train Loss: 0.8458
# Epoch: 88/100	 batch: 550/610	Train Loss: 0.8686
# Epoch: 88/100	 batch: 600/610	Train Loss: 0.8369
#
# Epoch 88/100	Train Loss: 0.8606	Test Loss: 0.8499	Train Acc: 0.8831	Test Acc: 0.8933	Best Acc: 0.8934
#
# Epoch: 89/100	 batch: 50/610	Train Loss: 0.8998
# Epoch: 89/100	 batch: 100/610	Train Loss: 0.8517
# Epoch: 89/100	 batch: 150/610	Train Loss: 0.8937
# Epoch: 89/100	 batch: 200/610	Train Loss: 0.8508
# Epoch: 89/100	 batch: 250/610	Train Loss: 0.8511
# Epoch: 89/100	 batch: 300/610	Train Loss: 0.8615
# Epoch: 89/100	 batch: 350/610	Train Loss: 0.8544
# Epoch: 89/100	 batch: 400/610	Train Loss: 0.8265
# Epoch: 89/100	 batch: 450/610	Train Loss: 0.8372
# Epoch: 89/100	 batch: 500/610	Train Loss: 0.8228
# Epoch: 89/100	 batch: 550/610	Train Loss: 0.8551
# Epoch: 89/100	 batch: 600/610	Train Loss: 0.8840
#
# Epoch 89/100	Train Loss: 0.8560	Test Loss: 0.8778	Train Acc: 0.8878	Test Acc: 0.8656	Best Acc: 0.8934
#
# Epoch: 90/100	 batch: 50/610	Train Loss: 0.8614
# Epoch: 90/100	 batch: 100/610	Train Loss: 0.8587
# Epoch: 90/100	 batch: 150/610	Train Loss: 0.8503
# Epoch: 90/100	 batch: 200/610	Train Loss: 0.8530
# Epoch: 90/100	 batch: 250/610	Train Loss: 0.8465
# Epoch: 90/100	 batch: 300/610	Train Loss: 0.8684
# Epoch: 90/100	 batch: 350/610	Train Loss: 0.8560
# Epoch: 90/100	 batch: 400/610	Train Loss: 0.8550
# Epoch: 90/100	 batch: 450/610	Train Loss: 0.8380
# Epoch: 90/100	 batch: 500/610	Train Loss: 0.8544
# Epoch: 90/100	 batch: 550/610	Train Loss: 0.8466
# Epoch: 90/100	 batch: 600/610	Train Loss: 0.8689
#
# Epoch 90/100	Train Loss: 0.8541	Test Loss: 0.8449	Train Acc: 0.8896	Test Acc: 0.8983	Best Acc: 0.8983
#
# Epoch: 91/100	 batch: 50/610	Train Loss: 0.8555
# Epoch: 91/100	 batch: 100/610	Train Loss: 0.8589
# Epoch: 91/100	 batch: 150/610	Train Loss: 0.8709
# Epoch: 91/100	 batch: 200/610	Train Loss: 0.8353
# Epoch: 91/100	 batch: 250/610	Train Loss: 0.8463
# Epoch: 91/100	 batch: 300/610	Train Loss: 0.9182
# Epoch: 91/100	 batch: 350/610	Train Loss: 0.8716
# Epoch: 91/100	 batch: 400/610	Train Loss: 0.8580
# Epoch: 91/100	 batch: 450/610	Train Loss: 0.8658
# Epoch: 91/100	 batch: 500/610	Train Loss: 0.8419
# Epoch: 91/100	 batch: 550/610	Train Loss: 0.8900
# Epoch: 91/100	 batch: 600/610	Train Loss: 0.8268
#
# Epoch 91/100	Train Loss: 0.8553	Test Loss: 0.8427	Train Acc: 0.8884	Test Acc: 0.9003	Best Acc: 0.9003
#
# Epoch: 92/100	 batch: 50/610	Train Loss: 0.8469
# Epoch: 92/100	 batch: 100/610	Train Loss: 0.8542
# Epoch: 92/100	 batch: 150/610	Train Loss: 0.8399
# Epoch: 92/100	 batch: 200/610	Train Loss: 0.8465
# Epoch: 92/100	 batch: 250/610	Train Loss: 0.8226
# Epoch: 92/100	 batch: 300/610	Train Loss: 0.8405
# Epoch: 92/100	 batch: 350/610	Train Loss: 0.8937
# Epoch: 92/100	 batch: 400/610	Train Loss: 0.8426
# Epoch: 92/100	 batch: 450/610	Train Loss: 0.8685
# Epoch: 92/100	 batch: 500/610	Train Loss: 0.8367
# Epoch: 92/100	 batch: 550/610	Train Loss: 0.8773
# Epoch: 92/100	 batch: 600/610	Train Loss: 0.8290
#
# Epoch 92/100	Train Loss: 0.8530	Test Loss: 0.8434	Train Acc: 0.8908	Test Acc: 0.8997	Best Acc: 0.9003
#
# Epoch: 93/100	 batch: 50/610	Train Loss: 0.8653
# Epoch: 93/100	 batch: 100/610	Train Loss: 0.8928
# Epoch: 93/100	 batch: 150/610	Train Loss: 0.8440
# Epoch: 93/100	 batch: 200/610	Train Loss: 0.8578
# Epoch: 93/100	 batch: 250/610	Train Loss: 0.8530
# Epoch: 93/100	 batch: 300/610	Train Loss: 0.8337
# Epoch: 93/100	 batch: 350/610	Train Loss: 0.8386
# Epoch: 93/100	 batch: 400/610	Train Loss: 0.8405
# Epoch: 93/100	 batch: 450/610	Train Loss: 0.8369
# Epoch: 93/100	 batch: 500/610	Train Loss: 0.8830
# Epoch: 93/100	 batch: 550/610	Train Loss: 0.8422
# Epoch: 93/100	 batch: 600/610	Train Loss: 0.8531
#
# Epoch 93/100	Train Loss: 0.8515	Test Loss: 0.8413	Train Acc: 0.8922	Test Acc: 0.9019	Best Acc: 0.9019
#
# Epoch: 94/100	 batch: 50/610	Train Loss: 0.8589
# Epoch: 94/100	 batch: 100/610	Train Loss: 0.8064
# Epoch: 94/100	 batch: 150/610	Train Loss: 0.8321
# Epoch: 94/100	 batch: 200/610	Train Loss: 0.8236
# Epoch: 94/100	 batch: 250/610	Train Loss: 0.8157
# Epoch: 94/100	 batch: 300/610	Train Loss: 0.8706
# Epoch: 94/100	 batch: 350/610	Train Loss: 0.8884
# Epoch: 94/100	 batch: 400/610	Train Loss: 0.8838
# Epoch: 94/100	 batch: 450/610	Train Loss: 0.8410
# Epoch: 94/100	 batch: 500/610	Train Loss: 0.8180
# Epoch: 94/100	 batch: 550/610	Train Loss: 0.8267
# Epoch: 94/100	 batch: 600/610	Train Loss: 0.8343
#
# Epoch 94/100	Train Loss: 0.8494	Test Loss: 0.8381	Train Acc: 0.8942	Test Acc: 0.9048	Best Acc: 0.9048
#
# Epoch: 95/100	 batch: 50/610	Train Loss: 0.8340
# Epoch: 95/100	 batch: 100/610	Train Loss: 0.8611
# Epoch: 95/100	 batch: 150/610	Train Loss: 0.8368
# Epoch: 95/100	 batch: 200/610	Train Loss: 0.8451
# Epoch: 95/100	 batch: 250/610	Train Loss: 0.8663
# Epoch: 95/100	 batch: 300/610	Train Loss: 0.8424
# Epoch: 95/100	 batch: 350/610	Train Loss: 0.8236
# Epoch: 95/100	 batch: 400/610	Train Loss: 0.8431
# Epoch: 95/100	 batch: 450/610	Train Loss: 0.8363
# Epoch: 95/100	 batch: 500/610	Train Loss: 0.8352
# Epoch: 95/100	 batch: 550/610	Train Loss: 0.8421
# Epoch: 95/100	 batch: 600/610	Train Loss: 0.8282
#
# Epoch 95/100	Train Loss: 0.8481	Test Loss: 0.8358	Train Acc: 0.8953	Test Acc: 0.9069	Best Acc: 0.9069
#
# Epoch: 96/100	 batch: 50/610	Train Loss: 0.8098
# Epoch: 96/100	 batch: 100/610	Train Loss: 0.8466
# Epoch: 96/100	 batch: 150/610	Train Loss: 0.8390
# Epoch: 96/100	 batch: 200/610	Train Loss: 0.8544
# Epoch: 96/100	 batch: 250/610	Train Loss: 0.8594
# Epoch: 96/100	 batch: 300/610	Train Loss: 0.8565
# Epoch: 96/100	 batch: 350/610	Train Loss: 0.8501
# Epoch: 96/100	 batch: 400/610	Train Loss: 0.8651
# Epoch: 96/100	 batch: 450/610	Train Loss: 0.8789
# Epoch: 96/100	 batch: 500/610	Train Loss: 0.8368
# Epoch: 96/100	 batch: 550/610	Train Loss: 0.8456
# Epoch: 96/100	 batch: 600/610	Train Loss: 0.8394
#
# Epoch 96/100	Train Loss: 0.8461	Test Loss: 0.8415	Train Acc: 0.8977	Test Acc: 0.9021	Best Acc: 0.9069
#
# Epoch: 97/100	 batch: 50/610	Train Loss: 0.8228
# Epoch: 97/100	 batch: 100/610	Train Loss: 0.8180
# Epoch: 97/100	 batch: 150/610	Train Loss: 0.8578
# Epoch: 97/100	 batch: 200/610	Train Loss: 0.8167
# Epoch: 97/100	 batch: 250/610	Train Loss: 0.8505
# Epoch: 97/100	 batch: 300/610	Train Loss: 0.8268
# Epoch: 97/100	 batch: 350/610	Train Loss: 0.8469
# Epoch: 97/100	 batch: 400/610	Train Loss: 0.8742
# Epoch: 97/100	 batch: 450/610	Train Loss: 0.8199
# Epoch: 97/100	 batch: 500/610	Train Loss: 0.8054
# Epoch: 97/100	 batch: 550/610	Train Loss: 0.8505
# Epoch: 97/100	 batch: 600/610	Train Loss: 0.8135
#
# Epoch 97/100	Train Loss: 0.8455	Test Loss: 0.8345	Train Acc: 0.8979	Test Acc: 0.9084	Best Acc: 0.9084
#
# Epoch: 98/100	 batch: 50/610	Train Loss: 0.8927
# Epoch: 98/100	 batch: 100/610	Train Loss: 0.8076
# Epoch: 98/100	 batch: 150/610	Train Loss: 0.8759
# Epoch: 98/100	 batch: 200/610	Train Loss: 0.8485
# Epoch: 98/100	 batch: 250/610	Train Loss: 0.8239
# Epoch: 98/100	 batch: 300/610	Train Loss: 0.8145
# Epoch: 98/100	 batch: 350/610	Train Loss: 0.8394
# Epoch: 98/100	 batch: 400/610	Train Loss: 0.8451
# Epoch: 98/100	 batch: 450/610	Train Loss: 0.8327
# Epoch: 98/100	 batch: 500/610	Train Loss: 0.8646
# Epoch: 98/100	 batch: 550/610	Train Loss: 0.8387
# Epoch: 98/100	 batch: 600/610	Train Loss: 0.8163
#
# Epoch 98/100	Train Loss: 0.8432	Test Loss: 0.8299	Train Acc: 0.9005	Test Acc: 0.9131	Best Acc: 0.9131
#
# Epoch: 99/100	 batch: 50/610	Train Loss: 0.8396
# Epoch: 99/100	 batch: 100/610	Train Loss: 0.8125
# Epoch: 99/100	 batch: 150/610	Train Loss: 0.8451
# Epoch: 99/100	 batch: 200/610	Train Loss: 0.8525
# Epoch: 99/100	 batch: 250/610	Train Loss: 0.8324
# Epoch: 99/100	 batch: 300/610	Train Loss: 0.8570
# Epoch: 99/100	 batch: 350/610	Train Loss: 0.8423
# Epoch: 99/100	 batch: 400/610	Train Loss: 0.7964
# Epoch: 99/100	 batch: 450/610	Train Loss: 0.8522
# Epoch: 99/100	 batch: 500/610	Train Loss: 0.8047
# Epoch: 99/100	 batch: 550/610	Train Loss: 0.8496
# Epoch: 99/100	 batch: 600/610	Train Loss: 0.8350
#
# Epoch 99/100	Train Loss: 0.8382	Test Loss: 0.8290	Train Acc: 0.9053	Test Acc: 0.9144	Best Acc: 0.9144
#
# Epoch: 100/100	 batch: 50/610	Train Loss: 0.8456
# Epoch: 100/100	 batch: 100/610	Train Loss: 0.8822
# Epoch: 100/100	 batch: 150/610	Train Loss: 0.8519
# Epoch: 100/100	 batch: 200/610	Train Loss: 0.8274
# Epoch: 100/100	 batch: 250/610	Train Loss: 0.8507
# Epoch: 100/100	 batch: 300/610	Train Loss: 0.8374
# Epoch: 100/100	 batch: 350/610	Train Loss: 0.8561
# Epoch: 100/100	 batch: 400/610	Train Loss: 0.8283
# Epoch: 100/100	 batch: 450/610	Train Loss: 0.8368
# Epoch: 100/100	 batch: 500/610	Train Loss: 0.8693
# Epoch: 100/100	 batch: 550/610	Train Loss: 0.8270
# Epoch: 100/100	 batch: 600/610	Train Loss: 0.8157
#
# Epoch 100/100	Train Loss: 0.8379	Test Loss: 0.8233	Train Acc: 0.9056	Test Acc: 0.9196	Best Acc: 0.9196

# %%
if not os.path.exists('/content/drive/MyDrive/EEGMODEL'):
  os.mkdir('/content/drive/MyDrive/EEGMODEL')

# Save only the model's state dictionary

model_name = f"{results['val_auc'][-1]*100:.2f}_{model_train}_sub{subjectNum}_e{EPOCHS}"
model_save_path = '/content/drive/MyDrive/EEGMODEL/' + model_name + '/'

if not os.path.exists(model_save_path):
  os.mkdir(model_save_path)

torch.save(model.state_dict(), model_save_path + model_name + '.pth')
torch.save(best_model_state, model_save_path + 'best_' + model_name + '.pth')

# results = {'loss': [], 'val_loss': [], 'auc': [], 'val_auc': []}
result_save_path = model_save_path + model_name + '.pkl'
with open(result_save_path, 'wb') as file:
    pickle.dump(results, file)

# %% [markdown]
# # MODEL EVALUATION

# %%
model.load_state_dict(torch.load(model_save_path + model_name + '.pth'))
model.to(device)

with open(model_save_path + model_name + '.pkl', 'rb') as file:
    results = pickle.load(file)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))  # Set the size for the Loss plot

# Plot Training Loss
plt.subplot(1, 2, 1)  # First position in a 1 row by 2 columns layout
plt.plot(results['loss'], label='Training Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
# Annotate the last point for Training Loss
plt.annotate(f'{results["loss"][-1]:.4f}',
             (len(results['loss'])-1, results['loss'][-1]),
             textcoords="offset points",
             xytext=(0,10),
             ha='center')

# Plot Validation Loss
plt.subplot(1, 2, 2)  # Second position in a 1 row by 2 columns layout
plt.plot(results['val_loss'], label='Validation Loss')
plt.title('Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
# Annotate the last point for Validation Loss
plt.annotate(f'{results["val_loss"][-1]:.4f}',
             (len(results['val_loss'])-1, results['val_loss'][-1]),
             textcoords="offset points",
             xytext=(0,10),
             ha='center')

plt.tight_layout()  # Automatically adjust subplot parameters to fit the figure area
plt.savefig(model_save_path + 'LOSS.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(10, 5))  # Set the size for the AUC plot

# Plot Training AUC
plt.subplot(1, 2, 1)  # First position in a 1 row by 2 columns layout
plt.plot(results['auc'], label='Training Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
# Annotate the last point for Training AUC
plt.annotate(f'{results["auc"][-1]:.4f}',
             (len(results['auc'])-1, results['auc'][-1]),
             textcoords="offset points",
             xytext=(0,10),
             ha='center')

# Plot Validation AUC
plt.subplot(1, 2, 2)  # Second position in a 1 row by 2 columns layout
plt.plot(results['val_auc'], label='Validation Accuracy')
plt.title('Validation Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
# Annotate the last point for Validation AUC
plt.annotate(f'{results["val_auc"][-1]:.4f}',
             (len(results['val_auc'])-1, results['val_auc'][-1]),
             textcoords="offset points",
             xytext=(0,10),
             ha='center')

plt.tight_layout()  # Automatically adjust subplot parameters to fit the figure area
plt.savefig(model_save_path + 'ACC.png', dpi=300)
plt.show()

# %%
# Test sample
id = 10
data_p, label_p = test_eeg_dataset[id]
data_p = data_p.to(device)
data_p = data_p.to(torch.float)

yhat = model.forward(data_p.to(device)).float() # Find predicted
label_p= label_p.float().to(device)                   # label to device

print(label_p)
print(yhat)
# Out:
# tensor([1., 0., 0., 0.], device='cuda:0')
# tensor([[9.9989e-01, 4.1897e-05, 2.1347e-05, 4.6597e-05]], device='cuda:0',
#        grad_fn=<SoftmaxBackward0>)

# %%
model.eval()
epoch_val_losses = []
epoch_val_aucs = []
with torch.no_grad():
    for x, y in test_eeg_dataloader:
        x    = x.squeeze(1)
        x    = x.to(torch.float)
        yhat = model.forward(x.to(device)).float() # Find predicted
        y    = y.float().to(device)                   # label to device

        # accuracy
        gt      = torch.argmax(y,dim=1)
        pred    = torch.argmax(yhat,dim=1)
        correct = (gt == pred).sum().item()
        epoch_val_aucs.append(correct)


epoch_val_auc  = np.sum(epoch_val_aucs) / len(test_eeg_dataset)
print('Accuracy: ', epoch_val_auc)
# Out:
# Accuracy:  0.9195952868852459
